# %%
# %load_ext autoreload
# %autoreload 2

# %% [markdown]
# # Step loading data

# %%
import pandas as pd
import numpy as np

# %%
from openproblems.tasks.regulatory_effect_prediction import datasets
adata = datasets.share_mouse_skin(test=False)
adata.shape
# Out:
# <style type='text/css'>
# .datatable table.frame { margin-bottom: 0; }
# .datatable table.frame thead { border-bottom: none; }
# .datatable table.frame tr.coltypes td {  color: #FFFFFF;  line-height: 6px;  padding: 0 0.5em;}
# .datatable .bool    { background: #DDDD99; }
# .datatable .object  { background: #565656; }
# .datatable .int     { background: #5D9E5D; }
# .datatable .float   { background: #4040CC; }
# .datatable .str     { background: #CC4040; }
# .datatable .row_index {  background: var(--jp-border-color3);  border-right: 1px solid var(--jp-border-color0);  color: var(--jp-ui-font-color3);  font-size: 9px;}
# .datatable .frame tr.coltypes .row_index {  background: var(--jp-border-color0);}
# .datatable th:nth-child(2) { padding-left: 12px; }
# .datatable .hellipsis {  color: var(--jp-cell-editor-border-color);}
# .datatable .vellipsis {  background: var(--jp-layout-color0);  color: var(--jp-cell-editor-border-color);}
# .datatable .na {  color: var(--jp-cell-editor-border-color);  font-size: 80%;}
# .datatable .footer { font-size: 9px; }
# .datatable .frame_dimensions {  background: var(--jp-border-color3);  border-top: 1px solid var(--jp-border-color0);  color: var(--jp-ui-font-color3);  display: inline-block;  opacity: 0.6;  padding: 1px 10px 1px 5px;}
# </style>
# (34774, 23076)

# %%
adata.uns['mode2_var_chr'].shape, adata.uns['mode2_var'].shape
# Out:
# ((344592,), (344592, 3))

# %%
adata.shape, adata.obsm['mode2'].shape
# Out:
# ((34774, 23076), (34774, 344592))

# %% [markdown]
# ## Copy of utility functions

# %%
from openproblems.patch import patch_datacache
import numpy as np
import pandas as pd
import scanpy as sc
import warnings

def _chrom_limit(x, tss_size=2e5):
    """Extend TSS to upstream and downstream intervals.

    Parameters
    ----------
    x : pd.Series
        a pd.Series containing [start, end, direction]
        where start and end are ints and direction is {'+', '-'}.
    tss_size: int
        a int that defines the upstream and downstream regions around TSS
    """
    y = x.values
    gene_direction = y[-1]
    gene_start = y[-3]
    gene_end = y[-2]
    if gene_direction == "+":
        return [gene_start - tss_size // 2, gene_start + tss_size // 2]
    else:
        return [gene_end - tss_size // 2, gene_end + tss_size // 2]


def _get_annotation(adata, retries=3):
    """Insert meta data into adata.obs."""
    from pyensembl import EnsemblRelease

    data = EnsemblRelease(
        adata.uns["release"],
        adata.uns["species"],
    )
    for _ in range(retries):
        try:
            with patch_datacache():
                data.download(overwrite=False)
                data.index(overwrite=False)
            break
        except TimeoutError:
            pass

    # get ensemble gene coordinate
    genes = []
    for i in adata.var.index.map(lambda x: x.split(".")[0]):
        try:
            with warnings.catch_warnings():
                warnings.filterwarnings(
                    action="ignore", message="No results found for query"
                )
                gene = data.gene_by_id(i)
            genes.append(
                [
                    "chr%s" % gene.contig,
                    gene.start,
                    gene.end,
                    gene.strand,
                ]
            )
        except ValueError:
            try:
                with warnings.catch_warnings():
                    warnings.filterwarnings(
                        action="ignore", message="No results found for query"
                    )
                    i = data.gene_ids_of_gene_name(i)[0]
                gene = data.gene_by_id(i)
                genes.append(
                    [
                        "chr%s" % gene.contig,
                        gene.start,
                        gene.end,
                        gene.strand,
                    ]
                )
            except (IndexError, ValueError) as e:
                print(e)
                genes.append([np.nan, np.nan, np.nan, np.nan])
    old_col = adata.var.columns.values
    adata.var = pd.concat(
        [adata.var, pd.DataFrame(genes, index=adata.var_names)], axis=1
    )
    adata.var.columns = np.hstack(
        [old_col, np.array(["chr", "start", "end", "strand"])]
    )


def _filter_mitochondrial(adata):
    if adata.uns["species"] in ["mus_musculus", "homo_sapiens"]:
        adata.var["mt"] = adata.var.gene_short_name.str.lower().str.startswith(
            "mt-"
        )  # annotate the group of mitochondrial genes as 'mt'
        sc.pp.calculate_qc_metrics(
            adata, qc_vars=["mt"], percent_top=None, log1p=False, inplace=True
        )

        adata_filter = adata[adata.obs.pct_counts_mt <= 10]
        if adata_filter.shape[0] > 100:
            adata = adata_filter.copy()
    return adata


def _filter_n_genes_max(adata):
    adata_filter = adata[adata.obs.n_genes_by_counts <= 2000]
    if adata_filter.shape[0] > 100:
        adata = adata_filter.copy()
    return adata


def _filter_n_genes_min(adata):
    adata_filter = adata.copy()
    sc.pp.filter_cells(adata_filter, min_genes=200)
    if adata_filter.shape[0] > 100:
        adata = adata_filter
    return adata


def _filter_n_cells(adata):
    adata_filter = adata.copy()
    sc.pp.filter_genes(adata_filter, min_cells=5)
    if adata_filter.shape[1] > 100:
        adata = adata_filter
    return adata


def _filter_has_chr(adata):
    adata_filter = adata[:, ~pd.isnull(adata.var.loc[:, "chr"])].copy()
    if adata_filter.shape[1] > 100:
        adata = adata_filter
    return adata

# %% [markdown]
# ## Get gene coordinates

# %%
_get_annotation(adata)
# Out:
# No results found for query:
#
#             SELECT distinct gene_id
#             FROM gene
#             WHERE gene_name = ?
#
# with parameters: ['0610007P14Rik']
# No results found for query:
#
#             SELECT distinct gene_id
#             FROM gene
#             WHERE gene_name = ?
#
# with parameters: ['0610009O20Rik']
# No results found for query:
#
#             SELECT distinct gene_id
#             FROM gene
#             WHERE gene_name = ?
#
# with parameters: ['0610011F06Rik']
# No results found for query:
#
#             SELECT distinct gene_id
#             FROM gene
#             WHERE gene_name = ?
#
# with parameters: ['0610037L13Rik']
# No results found for query:
#
#             SELECT distinct gene_id
#             FROM gene
#             WHERE gene_name = ?
#
# with parameters: ['1010001N08Rik']
# No results found for query:
#
#             SELECT distinct gene_id
#             FROM gene
#             WHERE gene_name = ?
#
# with parameters: ['1110001J03Rik']
# No results found for query:
#
#             SELECT distinct gene_id
#             FROM gene
#             WHERE gene_name = ?
#
# with parameters: ['1110004E09Rik']
# No results found for query:
#
#             SELECT distinct gene_id
#             FROM gene
#             WHERE gene_name = ?
#
# with parameters: ['1110008F13Rik']
# No results found for query:
#
#             SELECT distinct gene_id
#             FROM gene
#             WHERE gene_name = ?
#
# with parameters: ['1110008L16Rik']
# No results found for query:
#
#             SELECT distinct gene_id
#             FROM gene
#             WHERE gene_name = ?
#
# with parameters: ['1110034G24Rik']
# No results found for query:
#
#             SELECT distinct gene_id
#             FROM gene
#             WHERE gene_name = ?
#
# with parameters: ['1110036E04Rik']
# No results found for query:
#
#             SELECT distinct gene_id
#             FROM gene
#             WHERE gene_name = ?
#
# with parameters: ['1110037F02Rik']
# No results found for query:
#
#             SELECT distinct gene_id
#             FROM gene
#             WHERE gene_name = ?
#
# with parameters: ['1190002N15Rik']
# No results found for query:
#
#             SELECT distinct gene_id
#             FROM gene
#             WHERE gene_name = ?
#
# with parameters: ['1190003K10Rik']
# No results found for query:
#
#             SELECT distinct gene_id
#             FROM gene
#             WHERE gene_name = ?
#
# with parameters: ['1500011K16Rik']
# No results found for query:
#
#             SELECT distinct gene_id
#             FROM gene
#             WHERE gene_name = ?
#
# with parameters: ['1500015O10Rik']
# No results found for query:
#
#             SELECT distinct gene_id
#             FROM gene
#             WHERE gene_name = ?
#
# with parameters: ['1600002H07Rik']
# No results found for query:
#
#             SELECT distinct gene_id
#             FROM gene
#             WHERE gene_name = ?
#
# with parameters: ['1600002K03Rik']
# No results found for query:
#
#             SELECT distinct gene_id
#             FROM gene
#             WHERE gene_name = ?
#
# with parameters: ['1700001C02Rik']
# No results found for query:
#
#             SELECT distinct gene_id
#             FROM gene
#             WHERE gene_name = ?
#
# with parameters: ['1700003G13Rik']
# No results found for query:
#
#             SELECT distinct gene_id
#             FROM gene
#             WHERE gene_name = ?
#
# with parameters: ['1700006E09Rik']
# No results found for query:
#
#             SELECT distinct gene_id
#             FROM gene
#             WHERE gene_name = ?
#
# with parameters: ['1700007B14Rik']
# No results found for query:
#
#             SELECT distinct gene_id
#             FROM gene
#             WHERE gene_name = ?
#
# with parameters: ['1700007G11Rik']
# No results found for query:
#
#             SELECT distinct gene_id
#             FROM gene
#             WHERE gene_name = ?
#
# with parameters: ['1700007K09Rik']
# No results found for query:
#
#             SELECT distinct gene_id
#             FROM gene
#             WHERE gene_name = ?
#
# with parameters: ['1700011A15Rik']
# No results found for query:
#
#             SELECT distinct gene_id
#             FROM gene
#             WHERE gene_name = ?
#
# with parameters: ['1700011E24Rik']
# No results found for query:
#
#             SELECT distinct gene_id
#             FROM gene
#             WHERE gene_name = ?
#
# with parameters: ['1700011H14Rik']
# No results found for query:
#
#             SELECT distinct gene_id
#             FROM gene
#             WHERE gene_name = ?
#
# with parameters: ['1700011I03Rik']
# No results found for query:
#
#             SELECT distinct gene_id
#             FROM gene
#             WHERE gene_name = ?
#
# with parameters: ['1700015E13Rik']
# No results found for query:
#
#             SELECT distinct gene_id
#             FROM gene
#             WHERE gene_name = ?
#
# with parameters: ['1700016G14Rik']
# No results found for query:
#
#             SELECT distinct gene_id
#             FROM gene
#             WHERE gene_name = ?
#
# with parameters: ['1700017D01Rik']
# No results found for query:
#
#             SELECT distinct gene_id
#             FROM gene
#             WHERE gene_name = ?
#
# with parameters: ['1700018C11Rik']
# No results found for query:
#
#             SELECT distinct gene_id
#             FROM gene
#             WHERE gene_name = ?
#
# with parameters: ['1700019B03Rik']
# No results found for query:
#
#             SELECT distinct gene_id
#             FROM gene
#             WHERE gene_name = ?
#
# with parameters: ['1700019B21Rik']
# No results found for query:
#
#             SELECT distinct gene_id
#             FROM gene
#             WHERE gene_name = ?
#
# with parameters: ['1700019G17Rik']
# No results found for query:
#
#             SELECT distinct gene_id
#             FROM gene
#             WHERE gene_name = ?
#
# with parameters: ['1700020I14Rik']
# No results found for query:
#
#             SELECT distinct gene_id
#             FROM gene
#             WHERE gene_name = ?
#
# with parameters: ['1700021F05Rik']
# No results found for query:
#
#             SELECT distinct gene_id
#             FROM gene
#             WHERE gene_name = ?
#
# with parameters: ['1700022F17Rik']
# No results found for query:
#
#             SELECT distinct gene_id
#             FROM gene
#             WHERE gene_name = ?
#
# with parameters: ['1700023F06Rik']
# No results found for query:
#
#             SELECT distinct gene_id
#             FROM gene
#             WHERE gene_name = ?
#
# with parameters: ['1700024P16Rik']
# No results found for query:
#
#             SELECT distinct gene_id
#             FROM gene
#             WHERE gene_name = ?
#
# with parameters: ['1700025F22Rik']
# No results found for query:
#
#             SELECT distinct gene_id
#             FROM gene
#             WHERE gene_name = ?
#
# with parameters: ['1700026L06Rik']
# No results found for query:
#
#             SELECT distinct gene_id
#             FROM gene
#             WHERE gene_name = ?
#
# with parameters: ['1700040L02Rik']
# No results found for query:
#
#             SELECT distinct gene_id
#             FROM gene
#             WHERE gene_name = ?
#
# with parameters: ['1700047I17Rik2']
# No results found for query:
#
#             SELECT distinct gene_id
#             FROM gene
#             WHERE gene_name = ?
#
# with parameters: ['1700049G17Rik']
# No results found for query:
#
#             SELECT distinct gene_id
#             FROM gene
#             WHERE gene_name = ?
#
# with parameters: ['1700049J03Rik']
# No results found for query:
#
#             SELECT distinct gene_id
#             FROM gene
#             WHERE gene_name = ?
#
# with parameters: ['1700061G19Rik']
# No results found for query:
#
#             SELECT distinct gene_id
#             FROM gene
#             WHERE gene_name = ?
#
# with parameters: ['1700080E11Rik']
# No results found for query:
#
#             SELECT distinct gene_id
#             FROM gene
#             WHERE gene_name = ?
#
# with parameters: ['1700080G11Rik']
# No results found for query:
#
#             SELECT distinct gene_id
#             FROM gene
#             WHERE gene_name = ?
#
# with parameters: ['1700112E06Rik']
# No results found for query:
#
#             SELECT distinct gene_id
#             FROM gene
#             WHERE gene_name = ?
#
# with parameters: ['1700123I01Rik']
# No results found for query:
#
#             SELECT distinct gene_id
#             FROM gene
#             WHERE gene_name = ?
#
# with parameters: ['1810011H11Rik']
# No results found for query:
#
#             SELECT distinct gene_id
#             FROM gene
#             WHERE gene_name = ?
#
# with parameters: ['1810011O10Rik']
# No results found for query:
#
#             SELECT distinct gene_id
#             FROM gene
#             WHERE gene_name = ?
#
# with parameters: ['1810022K09Rik']
# No results found for query:
#
#             SELECT distinct gene_id
#             FROM gene
#             WHERE gene_name = ?
#
# with parameters: ['1810026J23Rik']
# No results found for query:
#
#             SELECT distinct gene_id
#             FROM gene
#             WHERE gene_name = ?
#
# with parameters: ['1810032O08Rik']
# No results found for query:
#
#             SELECT distinct gene_id
#             FROM gene
#             WHERE gene_name = ?
#
# with parameters: ['1810041L15Rik']
# No results found for query:
#
#             SELECT distinct gene_id
#             FROM gene
#             WHERE gene_name = ?
#
# with parameters: ['1810043G02Rik']
# No results found for query:
#
#             SELECT distinct gene_id
#             FROM gene
#             WHERE gene_name = ?
#
# with parameters: ['1810043H04Rik']
# No results found for query:
#
#             SELECT distinct gene_id
#             FROM gene
#             WHERE gene_name = ?
#
# with parameters: ['2010001E11Rik']
# No results found for query:
#
#             SELECT distinct gene_id
#             FROM gene
#             WHERE gene_name = ?
#
# with parameters: ['2010005H15Rik']
# No results found for query:
#
#             SELECT distinct gene_id
#             FROM gene
#             WHERE gene_name = ?
#
# with parameters: ['2010015M23Rik']
# No results found for query:
#
#             SELECT distinct gene_id
#             FROM gene
#             WHERE gene_name = ?
#
# with parameters: ['2010107E04Rik']
# No results found for query:
#
#             SELECT distinct gene_id
#             FROM gene
#             WHERE gene_name = ?
#
# with parameters: ['2010107G12Rik']
# No results found for query:
#
#             SELECT distinct gene_id
#             FROM gene
#             WHERE gene_name = ?
#
# with parameters: ['2010107G23Rik']
# No results found for query:
#
#             SELECT distinct gene_id
#             FROM gene
#             WHERE gene_name = ?
#
# with parameters: ['2010109I03Rik']
# No results found for query:
#
#             SELECT distinct gene_id
#             FROM gene
#             WHERE gene_name = ?
#
# with parameters: ['2010111I01Rik']
# No results found for query:
#
#             SELECT distinct gene_id
#             FROM gene
#             WHERE gene_name = ?
#
# with parameters: ['2010300F17Rik']
# No results found for query:
#
#             SELECT distinct gene_id
#             FROM gene
#             WHERE gene_name = ?
#
# with parameters: ['2210008F06Rik']
# No results found for query:
#
#             SELECT distinct gene_id
#             FROM gene
#             WHERE gene_name = ?
#
# with parameters: ['2210011C24Rik']
# No results found for query:
#
#             SELECT distinct gene_id
#             FROM gene
#             WHERE gene_name = ?
#
# with parameters: ['2210013O21Rik']
# No results found for query:
#
#             SELECT distinct gene_id
#             FROM gene
#             WHERE gene_name = ?
#
# with parameters: ['2210019I11Rik']
# No results found for query:
#
#             SELECT distinct gene_id
#             FROM gene
#             WHERE gene_name = ?
#
# with parameters: ['2210404O09Rik']
# No results found for query:
#
#             SELECT distinct gene_id
#             FROM gene
#             WHERE gene_name = ?
#
# with parameters: ['2300005B03Rik']
# No results found for query:
#
#             SELECT distinct gene_id
#             FROM gene
#             WHERE gene_name = ?
#
# with parameters: ['2310007B03Rik']
# No results found for query:
#
#             SELECT distinct gene_id
#             FROM gene
#             WHERE gene_name = ?
#
# with parameters: ['2310031A07Rik']
# No results found for query:
#
#             SELECT distinct gene_id
#             FROM gene
#             WHERE gene_name = ?
#
# with parameters: ['2310035C23Rik']
# No results found for query:
#
#             SELECT distinct gene_id
#             FROM gene
#             WHERE gene_name = ?
#
# with parameters: ['2310036O22Rik']
# No results found for query:
#
#             SELECT distinct gene_id
#             FROM gene
#             WHERE gene_name = ?
#
# with parameters: ['2310069G16Rik']
# No results found for query:
#
#             SELECT distinct gene_id
#             FROM gene
#             WHERE gene_name = ?
#
# with parameters: ['2410015M20Rik']
# No results found for query:
#
#             SELECT distinct gene_id
#             FROM gene
#             WHERE gene_name = ?
#
# with parameters: ['2410016O06Rik']
# No results found for query:
#
#             SELECT distinct gene_id
#             FROM gene
#             WHERE gene_name = ?
#
# with parameters: ['2410089E03Rik']
# No results found for query:
#
#             SELECT distinct gene_id
#             FROM gene
#             WHERE gene_name = ?
#
# with parameters: ['2610020H08Rik']
# No results found for query:
#
#             SELECT distinct gene_id
#             FROM gene
#             WHERE gene_name = ?
#
# with parameters: ['2610305D13Rik']
# No results found for query:
#
#             SELECT distinct gene_id
#             FROM gene
#             WHERE gene_name = ?
#
# with parameters: ['2610524H06Rik']
# No results found for query:
#
#             SELECT distinct gene_id
#             FROM gene
#             WHERE gene_name = ?
#
# with parameters: ['2700012I20Rik']
# No results found for query:
#
#             SELECT distinct gene_id
#             FROM gene
#             WHERE gene_name = ?
#
# with parameters: ['2700016F22Rik']
# No results found for query:
#
#             SELECT distinct gene_id
#             FROM gene
#             WHERE gene_name = ?
#
# with parameters: ['2700029M09Rik']
# No results found for query:
#
#             SELECT distinct gene_id
#             FROM gene
#             WHERE gene_name = ?
#
# with parameters: ['2700060E02Rik']
# No results found for query:
#
#             SELECT distinct gene_id
#             FROM gene
#             WHERE gene_name = ?
#
# with parameters: ['2700094K13Rik']
# No results found for query:
#
#             SELECT distinct gene_id
#             FROM gene
#             WHERE gene_name = ?
#
# with parameters: ['2810403A07Rik']
# No results found for query:
#
#             SELECT distinct gene_id
#             FROM gene
#             WHERE gene_name = ?
#
# with parameters: ['2810417H13Rik']
# No results found for query:
#
#             SELECT distinct gene_id
#             FROM gene
#             WHERE gene_name = ?
#
# with parameters: ['2810425M01Rik']
# No results found for query:
#
#             SELECT distinct gene_id
#             FROM gene
#             WHERE gene_name = ?
#
# with parameters: ['2810428I15Rik']
# No results found for query:
#
#             SELECT distinct gene_id
#             FROM gene
#             WHERE gene_name = ?
#
# with parameters: ['2810474O19Rik']
# No results found for query:
#
#             SELECT distinct gene_id
#             FROM gene
#             WHERE gene_name = ?
#
# with parameters: ['2900011O08Rik']
# No results found for query:
#
#             SELECT distinct gene_id
#             FROM gene
#             WHERE gene_name = ?
#
# with parameters: ['2900055J20Rik']
# No results found for query:
#
#             SELECT distinct gene_id
#             FROM gene
#             WHERE gene_name = ?
#
# with parameters: ['3010026O09Rik']
# No results found for query:
#
#             SELECT distinct gene_id
#             FROM gene
#             WHERE gene_name = ?
#
# with parameters: ['3100002H09Rik']
# No results found for query:
#
#             SELECT distinct gene_id
#             FROM gene
#             WHERE gene_name = ?
#
# with parameters: ['3110002H16Rik']
# No results found for query:
#
#             SELECT distinct gene_id
#             FROM gene
#             WHERE gene_name = ?
#
# with parameters: ['3110035E14Rik']
# No results found for query:
#
#             SELECT distinct gene_id
#             FROM gene
#             WHERE gene_name = ?
#
# with parameters: ['3110043O21Rik']
# No results found for query:
#
#             SELECT distinct gene_id
#             FROM gene
#             WHERE gene_name = ?
#
# with parameters: ['3110052M02Rik']
# No results found for query:
#
#             SELECT distinct gene_id
#             FROM gene
#             WHERE gene_name = ?
#
# with parameters: ['3110062M04Rik']
# No results found for query:
#
#             SELECT distinct gene_id
#             FROM gene
#             WHERE gene_name = ?
#
# with parameters: ['3110079O15Rik']
# No results found for query:
#
#             SELECT distinct gene_id
#             FROM gene
#             WHERE gene_name = ?
#
# with parameters: ['3632451O06Rik']
# No results found for query:
#
#             SELECT distinct gene_id
#             FROM gene
#             WHERE gene_name = ?
#
# with parameters: ['4631405K08Rik']
# No results found for query:
#
#             SELECT distinct gene_id
#             FROM gene
#             WHERE gene_name = ?
#
# with parameters: ['4732456N10Rik']
# No results found for query:
#
#             SELECT distinct gene_id
#             FROM gene
#             WHERE gene_name = ?
#
# with parameters: ['4831440E17Rik']
# No results found for query:
#
#             SELECT distinct gene_id
#             FROM gene
#             WHERE gene_name = ?
#
# with parameters: ['4833423E24Rik']
# No results found for query:
#
#             SELECT distinct gene_id
#             FROM gene
#             WHERE gene_name = ?
#
# with parameters: ['4921501E09Rik']
# No results found for query:
#
#             SELECT distinct gene_id
#             FROM gene
#             WHERE gene_name = ?
#
# with parameters: ['4921506M07Rik']
# No results found for query:
#
#             SELECT distinct gene_id
#             FROM gene
#             WHERE gene_name = ?
#
# with parameters: ['4921511H03Rik']
# No results found for query:
#
#             SELECT distinct gene_id
#             FROM gene
#             WHERE gene_name = ?
#
# with parameters: ['4921513D11Rik']
# No results found for query:
#
#             SELECT distinct gene_id
#             FROM gene
#             WHERE gene_name = ?
#
# with parameters: ['4922502D21Rik']
# No results found for query:
#
#             SELECT distinct gene_id
#             FROM gene
#             WHERE gene_name = ?
#
# with parameters: ['4930415F15Rik']
# No results found for query:
#
#             SELECT distinct gene_id
#             FROM gene
#             WHERE gene_name = ?
#
# with parameters: ['4930427A07Rik']
# No results found for query:
#
#             SELECT distinct gene_id
#             FROM gene
#             WHERE gene_name = ?
#
# with parameters: ['4930430A15Rik']
# No results found for query:
#
#             SELECT distinct gene_id
#             FROM gene
#             WHERE gene_name = ?
#
# with parameters: ['4930435E12Rik']
# No results found for query:
#
#             SELECT distinct gene_id
#             FROM gene
#             WHERE gene_name = ?
#
# with parameters: ['4930444M15Rik']
# No results found for query:
#
#             SELECT distinct gene_id
#             FROM gene
#             WHERE gene_name = ?
#
# with parameters: ['4930448N21Rik']
# No results found for query:
#
#             SELECT distinct gene_id
#             FROM gene
#             WHERE gene_name = ?
#
# with parameters: ['4930455D15Rik']
# No results found for query:
#
#             SELECT distinct gene_id
#             FROM gene
#             WHERE gene_name = ?
#
# with parameters: ['4930469G21Rik']
# No results found for query:
#
#             SELECT distinct gene_id
#             FROM gene
#             WHERE gene_name = ?
#
# with parameters: ['4930480K23Rik']
# No results found for query:
#
#             SELECT distinct gene_id
#             FROM gene
#             WHERE gene_name = ?
#
# with parameters: ['4930502E18Rik']
# No results found for query:
#
#             SELECT distinct gene_id
#             FROM gene
#             WHERE gene_name = ?
#
# with parameters: ['4930504O13Rik']
# No results found for query:
#
#             SELECT distinct gene_id
#             FROM gene
#             WHERE gene_name = ?
#
# with parameters: ['4930524J08Rik']
# No results found for query:
#
#             SELECT distinct gene_id
#             FROM gene
#             WHERE gene_name = ?
#
# with parameters: ['4930535I16Rik']
# No results found for query:
#
#             SELECT distinct gene_id
#             FROM gene
#             WHERE gene_name = ?
#
# with parameters: ['4930538K18Rik']
# No results found for query:
#
#             SELECT distinct gene_id
#             FROM gene
#             WHERE gene_name = ?
#
# with parameters: ['4930539E08Rik']
# No results found for query:
#
#             SELECT distinct gene_id
#             FROM gene
#             WHERE gene_name = ?
#
# with parameters: ['4930552P12Rik']
# No results found for query:
#
#             SELECT distinct gene_id
#             FROM gene
#             WHERE gene_name = ?
#
# with parameters: ['4930563D23Rik']
# No results found for query:
#
#             SELECT distinct gene_id
#             FROM gene
#             WHERE gene_name = ?
#
# with parameters: ['4930578C19Rik']
# No results found for query:
#
#             SELECT distinct gene_id
#             FROM gene
#             WHERE gene_name = ?
#
# with parameters: ['4930598A11Rik']
# No results found for query:
#
#             SELECT distinct gene_id
#             FROM gene
#             WHERE gene_name = ?
#
# with parameters: ['4931403G20Rik']
# No results found for query:
#
#             SELECT distinct gene_id
#             FROM gene
#             WHERE gene_name = ?
#
# with parameters: ['4931409K22Rik']
# No results found for query:
#
#             SELECT distinct gene_id
#             FROM gene
#             WHERE gene_name = ?
#
# with parameters: ['4931423N10Rik']
# No results found for query:
#
#             SELECT distinct gene_id
#             FROM gene
#             WHERE gene_name = ?
#
# with parameters: ['4931429I11Rik']
# No results found for query:
#
#             SELECT distinct gene_id
#             FROM gene
#             WHERE gene_name = ?
#
# with parameters: ['4931440F15Rik']
# No results found for query:
#
#             SELECT distinct gene_id
#             FROM gene
#             WHERE gene_name = ?
#
# with parameters: ['4931440J10Rik']
# No results found for query:
#
#             SELECT distinct gene_id
#             FROM gene
#             WHERE gene_name = ?
#
# with parameters: ['4932443I19Rik']
# No results found for query:
#
#             SELECT distinct gene_id
#             FROM gene
#             WHERE gene_name = ?
#
# with parameters: ['4933406J08Rik']
# No results found for query:
#
#             SELECT distinct gene_id
#             FROM gene
#             WHERE gene_name = ?
#
# with parameters: ['4933406M09Rik']
# No results found for query:
#
#             SELECT distinct gene_id
#             FROM gene
#             WHERE gene_name = ?
#
# with parameters: ['4933408B17Rik']
# No results found for query:
#
#             SELECT distinct gene_id
#             FROM gene
#             WHERE gene_name = ?
#
# with parameters: ['4933413G19Rik']
# No results found for query:
#
#             SELECT distinct gene_id
#             FROM gene
#             WHERE gene_name = ?
#
# with parameters: ['4933416C03Rik']
# No results found for query:
#
#             SELECT distinct gene_id
#             FROM gene
#             WHERE gene_name = ?
#
# with parameters: ['4933425L06Rik']
# No results found for query:
#
#             SELECT distinct gene_id
#             FROM gene
#             WHERE gene_name = ?
#
# with parameters: ['4933427G17Rik']
# No results found for query:
#
#             SELECT distinct gene_id
#             FROM gene
#             WHERE gene_name = ?
#
# with parameters: ['4933433C11Rik']
# No results found for query:
#
#             SELECT distinct gene_id
#             FROM gene
#             WHERE gene_name = ?
#
# with parameters: ['5031414D18Rik']
# No results found for query:
#
#             SELECT distinct gene_id
#             FROM gene
#             WHERE gene_name = ?
#
# with parameters: ['5430416O09Rik']
# No results found for query:
#
#             SELECT distinct gene_id
#             FROM gene
#             WHERE gene_name = ?
#
# with parameters: ['5430419D17Rik']
# No results found for query:
#
#             SELECT distinct gene_id
#             FROM gene
#             WHERE gene_name = ?
#
# with parameters: ['5430421N21Rik']
# No results found for query:
#
#             SELECT distinct gene_id
#             FROM gene
#             WHERE gene_name = ?
#
# with parameters: ['5730422E09Rik']
# No results found for query:
#
#             SELECT distinct gene_id
#             FROM gene
#             WHERE gene_name = ?
#
# with parameters: ['5730508B09Rik']
# No results found for query:
#
#             SELECT distinct gene_id
#             FROM gene
#             WHERE gene_name = ?
#
# with parameters: ['5730559C18Rik']
# No results found for query:
#
#             SELECT distinct gene_id
#             FROM gene
#             WHERE gene_name = ?
#
# with parameters: ['5830473C10Rik']
# No results found for query:
#
#             SELECT distinct gene_id
#             FROM gene
#             WHERE gene_name = ?
#
# with parameters: ['5930412G12Rik']
# No results found for query:
#
#             SELECT distinct gene_id
#             FROM gene
#             WHERE gene_name = ?
#
# with parameters: ['5930422O12Rik']
# No results found for query:
#
#             SELECT distinct gene_id
#             FROM gene
#             WHERE gene_name = ?
#
# with parameters: ['6030408B16Rik']
# No results found for query:
#
#             SELECT distinct gene_id
#             FROM gene
#             WHERE gene_name = ?
#
# with parameters: ['6030419C18Rik']
# No results found for query:
#
#             SELECT distinct gene_id
#             FROM gene
#             WHERE gene_name = ?
#
# with parameters: ['6330403A02Rik']
# No results found for query:
#
#             SELECT distinct gene_id
#             FROM gene
#             WHERE gene_name = ?
#
# with parameters: ['6330403N20Rik']
# No results found for query:
#
#             SELECT distinct gene_id
#             FROM gene
#             WHERE gene_name = ?
#
# with parameters: ['6330408A02Rik']
# No results found for query:
#
#             SELECT distinct gene_id
#             FROM gene
#             WHERE gene_name = ?
#
# with parameters: ['6330416G13Rik']
# No results found for query:
#
#             SELECT distinct gene_id
#             FROM gene
#             WHERE gene_name = ?
#
# with parameters: ['6430531B16Rik']
# No results found for query:
#
#             SELECT distinct gene_id
#             FROM gene
#             WHERE gene_name = ?
#
# with parameters: ['6430573F11Rik']
# No results found for query:
#
#             SELECT distinct gene_id
#             FROM gene
#             WHERE gene_name = ?
#
# with parameters: ['7420461P10Rik']
# No results found for query:
#
#             SELECT distinct gene_id
#             FROM gene
#             WHERE gene_name = ?
#
# with parameters: ['8030411F24Rik']
# No results found for query:
#
#             SELECT distinct gene_id
#             FROM gene
#             WHERE gene_name = ?
#
# with parameters: ['8430408G22Rik']
# No results found for query:
#
#             SELECT distinct gene_id
#             FROM gene
#             WHERE gene_name = ?
#
# with parameters: ['9030617O03Rik']
# No results found for query:
#
#             SELECT distinct gene_id
#             FROM gene
#             WHERE gene_name = ?
#
# with parameters: ['9030624J02Rik']
# No results found for query:
#
#             SELECT distinct gene_id
#             FROM gene
#             WHERE gene_name = ?
#
# with parameters: ['9130011E15Rik']
# No results found for query:
#
#             SELECT distinct gene_id
#             FROM gene
#             WHERE gene_name = ?
#
# with parameters: ['9130204L05Rik']
# No results found for query:
#
#             SELECT distinct gene_id
#             FROM gene
#             WHERE gene_name = ?
#
# with parameters: ['9130409J20Rik']
# No results found for query:
#
#             SELECT distinct gene_id
#             FROM gene
#             WHERE gene_name = ?
#
# with parameters: ['9230104L09Rik']
# No results found for query:
#
#             SELECT distinct gene_id
#             FROM gene
#             WHERE gene_name = ?
#
# with parameters: ['9230110C19Rik']
# No results found for query:
#
#             SELECT distinct gene_id
#             FROM gene
#             WHERE gene_name = ?
#
# with parameters: ['9230110F15Rik']
# No results found for query:
#
#             SELECT distinct gene_id
#             FROM gene
#             WHERE gene_name = ?
#
# with parameters: ['9430007A20Rik']
# No results found for query:
#
#             SELECT distinct gene_id
#             FROM gene
#             WHERE gene_name = ?
#
# with parameters: ['9430016H08Rik']
# No results found for query:
#
#             SELECT distinct gene_id
#             FROM gene
#             WHERE gene_name = ?
#
# with parameters: ['9430020K01Rik']
# No results found for query:
#
#             SELECT distinct gene_id
#             FROM gene
#             WHERE gene_name = ?
#
# with parameters: ['9530027J09Rik']
# No results found for query:
#
#             SELECT distinct gene_id
#             FROM gene
#             WHERE gene_name = ?
#
# with parameters: ['9830147E19Rik']
# No results found for query:
#
#             SELECT distinct gene_id
#             FROM gene
#             WHERE gene_name = ?
#
# with parameters: ['A130057D12Rik']
# No results found for query:
#
#             SELECT distinct gene_id
#             FROM gene
#             WHERE gene_name = ?
#
# with parameters: ['A230046K03Rik']
# No results found for query:
#
#             SELECT distinct gene_id
#             FROM gene
#             WHERE gene_name = ?
#
# with parameters: ['A230050P20Rik']
# No results found for query:
#
#             SELECT distinct gene_id
#             FROM gene
#             WHERE gene_name = ?
#
# with parameters: ['A230065H16Rik']
# No results found for query:
#
#             SELECT distinct gene_id
#             FROM gene
#             WHERE gene_name = ?
#
# with parameters: ['A330017A19Rik']
# No results found for query:
#
#             SELECT distinct gene_id
#             FROM gene
#             WHERE gene_name = ?
#
# with parameters: ['A330050F15Rik']
# No results found for query:
#
#             SELECT distinct gene_id
#             FROM gene
#             WHERE gene_name = ?
#
# with parameters: ['A330069E16Rik']
# No results found for query:
#
#             SELECT distinct gene_id
#             FROM gene
#             WHERE gene_name = ?
#
# with parameters: ['A430046D13Rik']
# No results found for query:
#
#             SELECT distinct gene_id
#             FROM gene
#             WHERE gene_name = ?
#
# with parameters: ['A430078G23Rik']
# No results found for query:
#
#             SELECT distinct gene_id
#             FROM gene
#             WHERE gene_name = ?
#
# with parameters: ['A430105I19Rik']
# No results found for query:
#
#             SELECT distinct gene_id
#             FROM gene
#             WHERE gene_name = ?
#
# with parameters: ['A430106G13Rik']
# No results found for query:
#
#             SELECT distinct gene_id
#             FROM gene
#             WHERE gene_name = ?
#
# with parameters: ['A630033H20Rik']
# No results found for query:
#
#             SELECT distinct gene_id
#             FROM gene
#             WHERE gene_name = ?
#
# with parameters: ['A630077J23Rik']
# No results found for query:
#
#             SELECT distinct gene_id
#             FROM gene
#             WHERE gene_name = ?
#
# with parameters: ['A630095E13Rik']
# No results found for query:
#
#             SELECT distinct gene_id
#             FROM gene
#             WHERE gene_name = ?
#
# with parameters: ['A730015C16Rik']
# No results found for query:
#
#             SELECT distinct gene_id
#             FROM gene
#             WHERE gene_name = ?
#
# with parameters: ['A730017C20Rik']
# No results found for query:
#
#             SELECT distinct gene_id
#             FROM gene
#             WHERE gene_name = ?
#
# with parameters: ['A830010M20Rik']
# No results found for query:
#
#             SELECT distinct gene_id
#             FROM gene
#             WHERE gene_name = ?
#
# with parameters: ['A830039N20Rik']
# No results found for query:
#
#             SELECT distinct gene_id
#             FROM gene
#             WHERE gene_name = ?
#
# with parameters: ['A830080D01Rik']
# No results found for query:
#
#             SELECT distinct gene_id
#             FROM gene
#             WHERE gene_name = ?
#
# with parameters: ['A930011G23Rik']
# No results found for query:
#
#             SELECT distinct gene_id
#             FROM gene
#             WHERE gene_name = ?
#
# with parameters: ['A930018M24Rik']
# No results found for query:
#
#             SELECT distinct gene_id
#             FROM gene
#             WHERE gene_name = ?
#
# with parameters: ['A930024N18Rik']
# No results found for query:
#
#             SELECT distinct gene_id
#             FROM gene
#             WHERE gene_name = ?
#
# with parameters: ['AA415398']
# No results found for query:
#
#             SELECT distinct gene_id
#             FROM gene
#             WHERE gene_name = ?
#
# with parameters: ['AA474331']
# No results found for query:
#
#             SELECT distinct gene_id
#             FROM gene
#             WHERE gene_name = ?
#
# with parameters: ['AA543186']
# No results found for query:
#
#             SELECT distinct gene_id
#             FROM gene
#             WHERE gene_name = ?
#
# with parameters: ['AC124606']
# No results found for query:
#
#             SELECT distinct gene_id
#             FROM gene
#             WHERE gene_name = ?
#
# with parameters: ['AC125149']
# No results found for query:
#
#             SELECT distinct gene_id
#             FROM gene
#             WHERE gene_name = ?
#
# with parameters: ['AC133103']
# No results found for query:
#
#             SELECT distinct gene_id
#             FROM gene
#             WHERE gene_name = ?
#
# with parameters: ['AC163611']
# No results found for query:
#
#             SELECT distinct gene_id
#             FROM gene
#             WHERE gene_name = ?
#
# with parameters: ['AC168977']
# No results found for query:
#
#             SELECT distinct gene_id
#             FROM gene
#             WHERE gene_name = ?
#
# with parameters: ['AF251705']
# No results found for query:
#
#             SELECT distinct gene_id
#             FROM gene
#             WHERE gene_name = ?
#
# with parameters: ['AF529169']
# No results found for query:
#
#             SELECT distinct gene_id
#             FROM gene
#             WHERE gene_name = ?
#
# with parameters: ['AI314180']
# No results found for query:
#
#             SELECT distinct gene_id
#             FROM gene
#             WHERE gene_name = ?
#
# with parameters: ['AI317395']
# No results found for query:
#
#             SELECT distinct gene_id
#             FROM gene
#             WHERE gene_name = ?
#
# with parameters: ['AI464131']
# No results found for query:
#
#             SELECT distinct gene_id
#             FROM gene
#             WHERE gene_name = ?
#
# with parameters: ['AI481877']
# No results found for query:
#
#             SELECT distinct gene_id
#             FROM gene
#             WHERE gene_name = ?
#
# with parameters: ['AI606181']
# No results found for query:
#
#             SELECT distinct gene_id
#             FROM gene
#             WHERE gene_name = ?
#
# with parameters: ['AI607873']
# No results found for query:
#
#             SELECT distinct gene_id
#             FROM gene
#             WHERE gene_name = ?
#
# with parameters: ['AI846148']
# No results found for query:
#
#             SELECT distinct gene_id
#             FROM gene
#             WHERE gene_name = ?
#
# with parameters: ['AI854517']
# No results found for query:
#
#             SELECT distinct gene_id
#             FROM gene
#             WHERE gene_name = ?
#
# with parameters: ['AK010878']
# No results found for query:
#
#             SELECT distinct gene_id
#             FROM gene
#             WHERE gene_name = ?
#
# with parameters: ['AU019823']
# No results found for query:
#
#             SELECT distinct gene_id
#             FROM gene
#             WHERE gene_name = ?
#
# with parameters: ['AW121686']
# No results found for query:
#
#             SELECT distinct gene_id
#             FROM gene
#             WHERE gene_name = ?
#
# with parameters: ['Aaed1']
# No results found for query:
#
#             SELECT distinct gene_id
#             FROM gene
#             WHERE gene_name = ?
#
# with parameters: ['Acpt']
# No results found for query:
#
#             SELECT distinct gene_id
#             FROM gene
#             WHERE gene_name = ?
#
# with parameters: ['Adck3']
# No results found for query:
#
#             SELECT distinct gene_id
#             FROM gene
#             WHERE gene_name = ?
#
# with parameters: ['Adck4']
# No results found for query:
#
#             SELECT distinct gene_id
#             FROM gene
#             WHERE gene_name = ?
#
# with parameters: ['Adrbk1']
# No results found for query:
#
#             SELECT distinct gene_id
#             FROM gene
#             WHERE gene_name = ?
#
# with parameters: ['Adrbk2']
# No results found for query:
#
#             SELECT distinct gene_id
#             FROM gene
#             WHERE gene_name = ?
#
# with parameters: ['Aes']
# No results found for query:
#
#             SELECT distinct gene_id
#             FROM gene
#             WHERE gene_name = ?
#
# with parameters: ['Agpat9']
# No results found for query:
#
#             SELECT distinct gene_id
#             FROM gene
#             WHERE gene_name = ?
#
# with parameters: ['Aim1']
# No results found for query:
#
#             SELECT distinct gene_id
#             FROM gene
#             WHERE gene_name = ?
#
# with parameters: ['Aim1l']
# No results found for query:
#
#             SELECT distinct gene_id
#             FROM gene
#             WHERE gene_name = ?
#
# with parameters: ['Akap2']
# No results found for query:
#
#             SELECT distinct gene_id
#             FROM gene
#             WHERE gene_name = ?
#
# with parameters: ['Als2cr11']
# No results found for query:
#
#             SELECT distinct gene_id
#             FROM gene
#             WHERE gene_name = ?
#
# with parameters: ['Als2cr12']
# No results found for query:
#
#             SELECT distinct gene_id
#             FROM gene
#             WHERE gene_name = ?
#
# with parameters: ['Amica1']
# No results found for query:
#
#             SELECT distinct gene_id
#             FROM gene
#             WHERE gene_name = ?
#
# with parameters: ['Apitd1']
# No results found for query:
#
#             SELECT distinct gene_id
#             FROM gene
#             WHERE gene_name = ?
#
# with parameters: ['Apoa1bp']
# No results found for query:
#
#             SELECT distinct gene_id
#             FROM gene
#             WHERE gene_name = ?
#
# with parameters: ['Asun']
# No results found for query:
#
#             SELECT distinct gene_id
#             FROM gene
#             WHERE gene_name = ?
#
# with parameters: ['Athl1']
# No results found for query:
#
#             SELECT distinct gene_id
#             FROM gene
#             WHERE gene_name = ?
#
# with parameters: ['Atp5f1']
# No results found for query:
#
#             SELECT distinct gene_id
#             FROM gene
#             WHERE gene_name = ?
#
# with parameters: ['Atp5s']
# No results found for query:
#
#             SELECT distinct gene_id
#             FROM gene
#             WHERE gene_name = ?
#
# with parameters: ['Atp5sl']
# No results found for query:
#
#             SELECT distinct gene_id
#             FROM gene
#             WHERE gene_name = ?
#
# with parameters: ['B130006D01Rik']
# No results found for query:
#
#             SELECT distinct gene_id
#             FROM gene
#             WHERE gene_name = ?
#
# with parameters: ['B230344G16Rik']
# No results found for query:
#
#             SELECT distinct gene_id
#             FROM gene
#             WHERE gene_name = ?
#
# with parameters: ['B630005N14Rik']
# No results found for query:
#
#             SELECT distinct gene_id
#             FROM gene
#             WHERE gene_name = ?
#
# with parameters: ['B930041F14Rik']
# No results found for query:
#
#             SELECT distinct gene_id
#             FROM gene
#             WHERE gene_name = ?
#
# with parameters: ['B930082K07Rik']
# No results found for query:
#
#             SELECT distinct gene_id
#             FROM gene
#             WHERE gene_name = ?
#
# with parameters: ['BC003331']
# No results found for query:
#
#             SELECT distinct gene_id
#             FROM gene
#             WHERE gene_name = ?
#
# with parameters: ['BC005561']
# No results found for query:
#
#             SELECT distinct gene_id
#             FROM gene
#             WHERE gene_name = ?
#
# with parameters: ['BC017643']
# No results found for query:
#
#             SELECT distinct gene_id
#             FROM gene
#             WHERE gene_name = ?
#
# with parameters: ['BC021614']
# No results found for query:
#
#             SELECT distinct gene_id
#             FROM gene
#             WHERE gene_name = ?
#
# with parameters: ['BC021785']
# No results found for query:
#
#             SELECT distinct gene_id
#             FROM gene
#             WHERE gene_name = ?
#
# with parameters: ['BC021891']
# No results found for query:
#
#             SELECT distinct gene_id
#             FROM gene
#             WHERE gene_name = ?
#
# with parameters: ['BC022687']
# No results found for query:
#
#             SELECT distinct gene_id
#             FROM gene
#             WHERE gene_name = ?
#
# with parameters: ['BC023829']
# No results found for query:
#
#             SELECT distinct gene_id
#             FROM gene
#             WHERE gene_name = ?
#
# with parameters: ['BC025446']
# No results found for query:
#
#             SELECT distinct gene_id
#             FROM gene
#             WHERE gene_name = ?
#
# with parameters: ['BC026585']
# No results found for query:
#
#             SELECT distinct gene_id
#             FROM gene
#             WHERE gene_name = ?
#
# with parameters: ['BC027072']
# No results found for query:
#
#             SELECT distinct gene_id
#             FROM gene
#             WHERE gene_name = ?
#
# with parameters: ['BC029214']
# No results found for query:
#
#             SELECT distinct gene_id
#             FROM gene
#             WHERE gene_name = ?
#
# with parameters: ['BC030336']
# No results found for query:
#
#             SELECT distinct gene_id
#             FROM gene
#             WHERE gene_name = ?
#
# with parameters: ['BC030499']
# No results found for query:
#
#             SELECT distinct gene_id
#             FROM gene
#             WHERE gene_name = ?
#
# with parameters: ['BC030867']
# No results found for query:
#
#             SELECT distinct gene_id
#             FROM gene
#             WHERE gene_name = ?
#
# with parameters: ['BC030870']
# No results found for query:
#
#             SELECT distinct gene_id
#             FROM gene
#             WHERE gene_name = ?
#
# with parameters: ['BC037034']
# No results found for query:
#
#             SELECT distinct gene_id
#             FROM gene
#             WHERE gene_name = ?
#
# with parameters: ['BC048502']
# No results found for query:
#
#             SELECT distinct gene_id
#             FROM gene
#             WHERE gene_name = ?
#
# with parameters: ['BC048546']
# No results found for query:
#
#             SELECT distinct gene_id
#             FROM gene
#             WHERE gene_name = ?
#
# with parameters: ['BC048609']
# No results found for query:
#
#             SELECT distinct gene_id
#             FROM gene
#             WHERE gene_name = ?
#
# with parameters: ['BC051628']
# No results found for query:
#
#             SELECT distinct gene_id
#             FROM gene
#             WHERE gene_name = ?
#
# with parameters: ['BC068281']
# No results found for query:
#
#             SELECT distinct gene_id
#             FROM gene
#             WHERE gene_name = ?
#
# with parameters: ['BC089491']
# No results found for query:
#
#             SELECT distinct gene_id
#             FROM gene
#             WHERE gene_name = ?
#
# with parameters: ['BC089597']
# No results found for query:
#
#             SELECT distinct gene_id
#             FROM gene
#             WHERE gene_name = ?
#
# with parameters: ['BC094916']
# No results found for query:
#
#             SELECT distinct gene_id
#             FROM gene
#             WHERE gene_name = ?
#
# with parameters: ['BC100451']
# No results found for query:
#
#             SELECT distinct gene_id
#             FROM gene
#             WHERE gene_name = ?
#
# with parameters: ['BC100530']
# No results found for query:
#
#             SELECT distinct gene_id
#             FROM gene
#             WHERE gene_name = ?
#
# with parameters: ['BC117090']
# No results found for query:
#
#             SELECT distinct gene_id
#             FROM gene
#             WHERE gene_name = ?
#
# with parameters: ['Bre']
# No results found for query:
#
#             SELECT distinct gene_id
#             FROM gene
#             WHERE gene_name = ?
#
# with parameters: ['Btg1-ps1']
# No results found for query:
#
#             SELECT distinct gene_id
#             FROM gene
#             WHERE gene_name = ?
#
# with parameters: ['Bzrap1']
# No results found for query:
#
#             SELECT distinct gene_id
#             FROM gene
#             WHERE gene_name = ?
#
# with parameters: ['C030039L03Rik']
# No results found for query:
#
#             SELECT distinct gene_id
#             FROM gene
#             WHERE gene_name = ?
#
# with parameters: ['C130060K24Rik']
# No results found for query:
#
#             SELECT distinct gene_id
#             FROM gene
#             WHERE gene_name = ?
#
# with parameters: ['C130079G13Rik']
# No results found for query:
#
#             SELECT distinct gene_id
#             FROM gene
#             WHERE gene_name = ?
#
# with parameters: ['C230021G24Rik']
# No results found for query:
#
#             SELECT distinct gene_id
#             FROM gene
#             WHERE gene_name = ?
#
# with parameters: ['C230088H06Rik']
# No results found for query:
#
#             SELECT distinct gene_id
#             FROM gene
#             WHERE gene_name = ?
#
# with parameters: ['C330006A16Rik']
# No results found for query:
#
#             SELECT distinct gene_id
#             FROM gene
#             WHERE gene_name = ?
#
# with parameters: ['C330013J21Rik']
# No results found for query:
#
#             SELECT distinct gene_id
#             FROM gene
#             WHERE gene_name = ?
#
# with parameters: ['C330021F23Rik']
# No results found for query:
#
#             SELECT distinct gene_id
#             FROM gene
#             WHERE gene_name = ?
#
# with parameters: ['C330027C09Rik']
# No results found for query:
#
#             SELECT distinct gene_id
#             FROM gene
#             WHERE gene_name = ?
#
# with parameters: ['C530050E15Rik']
# No results found for query:
#
#             SELECT distinct gene_id
#             FROM gene
#             WHERE gene_name = ?
#
# with parameters: ['C77370']
# No results found for query:
#
#             SELECT distinct gene_id
#             FROM gene
#             WHERE gene_name = ?
#
# with parameters: ['CAAA01147332']
# No results found for query:
#
#             SELECT distinct gene_id
#             FROM gene
#             WHERE gene_name = ?
#
# with parameters: ['CAAA01165726']
# No results found for query:
#
#             SELECT distinct gene_id
#             FROM gene
#             WHERE gene_name = ?
#
# with parameters: ['CT868723']
# ...
#             FROM gene
#             WHERE gene_name = ?
#
# with parameters: ['Rqcd1']
# No results found for query:
#
#             SELECT distinct gene_id
#             FROM gene
#             WHERE gene_name = ?
#
# with parameters: ['Rsg1']
# No results found for query:
#
#             SELECT distinct gene_id
#             FROM gene
#             WHERE gene_name = ?
#
# with parameters: ['Rtfdc1']
# No results found for query:
#
#             SELECT distinct gene_id
#             FROM gene
#             WHERE gene_name = ?
#
# with parameters: ['SDR42E2']
# No results found for query:
#
#             SELECT distinct gene_id
#             FROM gene
#             WHERE gene_name = ?
#
# with parameters: ['Scn2a1']
# No results found for query:
#
#             SELECT distinct gene_id
#             FROM gene
#             WHERE gene_name = ?
#
# with parameters: ['Sdccag3']
# No results found for query:
#
#             SELECT distinct gene_id
#             FROM gene
#             WHERE gene_name = ?
#
# with parameters: ['Sdpr']
# No results found for query:
#
#             SELECT distinct gene_id
#             FROM gene
#             WHERE gene_name = ?
#
# with parameters: ['Selk']
# No results found for query:
#
#             SELECT distinct gene_id
#             FROM gene
#             WHERE gene_name = ?
#
# with parameters: ['Selm']
# No results found for query:
#
#             SELECT distinct gene_id
#             FROM gene
#             WHERE gene_name = ?
#
# with parameters: ['Selo']
# No results found for query:
#
#             SELECT distinct gene_id
#             FROM gene
#             WHERE gene_name = ?
#
# with parameters: ['Selt']
# No results found for query:
#
#             SELECT distinct gene_id
#             FROM gene
#             WHERE gene_name = ?
#
# with parameters: ['Sep15']
# No results found for query:
#
#             SELECT distinct gene_id
#             FROM gene
#             WHERE gene_name = ?
#
# with parameters: ['Sepn1']
# No results found for query:
#
#             SELECT distinct gene_id
#             FROM gene
#             WHERE gene_name = ?
#
# with parameters: ['Sepp1']
# No results found for query:
#
#             SELECT distinct gene_id
#             FROM gene
#             WHERE gene_name = ?
#
# with parameters: ['Sept1']
# No results found for query:
#
#             SELECT distinct gene_id
#             FROM gene
#             WHERE gene_name = ?
#
# with parameters: ['Sept10']
# No results found for query:
#
#             SELECT distinct gene_id
#             FROM gene
#             WHERE gene_name = ?
#
# with parameters: ['Sept11']
# No results found for query:
#
#             SELECT distinct gene_id
#             FROM gene
#             WHERE gene_name = ?
#
# with parameters: ['Sept12']
# No results found for query:
#
#             SELECT distinct gene_id
#             FROM gene
#             WHERE gene_name = ?
#
# with parameters: ['Sept14']
# No results found for query:
#
#             SELECT distinct gene_id
#             FROM gene
#             WHERE gene_name = ?
#
# with parameters: ['Sept2']
# No results found for query:
#
#             SELECT distinct gene_id
#             FROM gene
#             WHERE gene_name = ?
#
# with parameters: ['Sept3']
# No results found for query:
#
#             SELECT distinct gene_id
#             FROM gene
#             WHERE gene_name = ?
#
# with parameters: ['Sept4']
# No results found for query:
#
#             SELECT distinct gene_id
#             FROM gene
#             WHERE gene_name = ?
#
# with parameters: ['Sept5']
# No results found for query:
#
#             SELECT distinct gene_id
#             FROM gene
#             WHERE gene_name = ?
#
# with parameters: ['Sept6']
# No results found for query:
#
#             SELECT distinct gene_id
#             FROM gene
#             WHERE gene_name = ?
#
# with parameters: ['Sept7']
# No results found for query:
#
#             SELECT distinct gene_id
#             FROM gene
#             WHERE gene_name = ?
#
# with parameters: ['Sept8']
# No results found for query:
#
#             SELECT distinct gene_id
#             FROM gene
#             WHERE gene_name = ?
#
# with parameters: ['Sept9']
# No results found for query:
#
#             SELECT distinct gene_id
#             FROM gene
#             WHERE gene_name = ?
#
# with parameters: ['Sepw1']
# No results found for query:
#
#             SELECT distinct gene_id
#             FROM gene
#             WHERE gene_name = ?
#
# with parameters: ['Setd8']
# No results found for query:
#
#             SELECT distinct gene_id
#             FROM gene
#             WHERE gene_name = ?
#
# with parameters: ['Sgol1']
# No results found for query:
#
#             SELECT distinct gene_id
#             FROM gene
#             WHERE gene_name = ?
#
# with parameters: ['Sgol2a']
# No results found for query:
#
#             SELECT distinct gene_id
#             FROM gene
#             WHERE gene_name = ?
#
# with parameters: ['Sgol2b']
# No results found for query:
#
#             SELECT distinct gene_id
#             FROM gene
#             WHERE gene_name = ?
#
# with parameters: ['Shfm1']
# No results found for query:
#
#             SELECT distinct gene_id
#             FROM gene
#             WHERE gene_name = ?
#
# with parameters: ['Skiv2l2']
# No results found for query:
#
#             SELECT distinct gene_id
#             FROM gene
#             WHERE gene_name = ?
#
# with parameters: ['Slmo1']
# No results found for query:
#
#             SELECT distinct gene_id
#             FROM gene
#             WHERE gene_name = ?
#
# with parameters: ['Slmo2']
# No results found for query:
#
#             SELECT distinct gene_id
#             FROM gene
#             WHERE gene_name = ?
#
# with parameters: ['Smek1']
# No results found for query:
#
#             SELECT distinct gene_id
#             FROM gene
#             WHERE gene_name = ?
#
# with parameters: ['Smek2']
# No results found for query:
#
#             SELECT distinct gene_id
#             FROM gene
#             WHERE gene_name = ?
#
# with parameters: ['Spert']
# No results found for query:
#
#             SELECT distinct gene_id
#             FROM gene
#             WHERE gene_name = ?
#
# with parameters: ['Sqrdl']
# No results found for query:
#
#             SELECT distinct gene_id
#             FROM gene
#             WHERE gene_name = ?
#
# with parameters: ['Ssfa2']
# No results found for query:
#
#             SELECT distinct gene_id
#             FROM gene
#             WHERE gene_name = ?
#
# with parameters: ['Sssca1']
# No results found for query:
#
#             SELECT distinct gene_id
#             FROM gene
#             WHERE gene_name = ?
#
# with parameters: ['St5']
# No results found for query:
#
#             SELECT distinct gene_id
#             FROM gene
#             WHERE gene_name = ?
#
# with parameters: ['Stra13']
# No results found for query:
#
#             SELECT distinct gene_id
#             FROM gene
#             WHERE gene_name = ?
#
# with parameters: ['Suv420h1']
# No results found for query:
#
#             SELECT distinct gene_id
#             FROM gene
#             WHERE gene_name = ?
#
# with parameters: ['Suv420h2']
# No results found for query:
#
#             SELECT distinct gene_id
#             FROM gene
#             WHERE gene_name = ?
#
# with parameters: ['Taf4a']
# No results found for query:
#
#             SELECT distinct gene_id
#             FROM gene
#             WHERE gene_name = ?
#
# with parameters: ['Tceb1']
# No results found for query:
#
#             SELECT distinct gene_id
#             FROM gene
#             WHERE gene_name = ?
#
# with parameters: ['Tceb2']
# No results found for query:
#
#             SELECT distinct gene_id
#             FROM gene
#             WHERE gene_name = ?
#
# with parameters: ['Tceb3']
# No results found for query:
#
#             SELECT distinct gene_id
#             FROM gene
#             WHERE gene_name = ?
#
# with parameters: ['Tex13']
# No results found for query:
#
#             SELECT distinct gene_id
#             FROM gene
#             WHERE gene_name = ?
#
# with parameters: ['Tex19']
# No results found for query:
#
#             SELECT distinct gene_id
#             FROM gene
#             WHERE gene_name = ?
#
# with parameters: ['Tex40']
# No results found for query:
#
#             SELECT distinct gene_id
#             FROM gene
#             WHERE gene_name = ?
#
# with parameters: ['Tldc1']
# No results found for query:
#
#             SELECT distinct gene_id
#             FROM gene
#             WHERE gene_name = ?
#
# with parameters: ['Tmem110']
# No results found for query:
#
#             SELECT distinct gene_id
#             FROM gene
#             WHERE gene_name = ?
#
# with parameters: ['Tmem136']
# No results found for query:
#
#             SELECT distinct gene_id
#             FROM gene
#             WHERE gene_name = ?
#
# with parameters: ['Tmem173']
# No results found for query:
#
#             SELECT distinct gene_id
#             FROM gene
#             WHERE gene_name = ?
#
# with parameters: ['Tmem180']
# No results found for query:
#
#             SELECT distinct gene_id
#             FROM gene
#             WHERE gene_name = ?
#
# with parameters: ['Tmem194']
# No results found for query:
#
#             SELECT distinct gene_id
#             FROM gene
#             WHERE gene_name = ?
#
# with parameters: ['Tmem194b']
# No results found for query:
#
#             SELECT distinct gene_id
#             FROM gene
#             WHERE gene_name = ?
#
# with parameters: ['Tmem2']
# No results found for query:
#
#             SELECT distinct gene_id
#             FROM gene
#             WHERE gene_name = ?
#
# with parameters: ['Tmem206']
# No results found for query:
#
#             SELECT distinct gene_id
#             FROM gene
#             WHERE gene_name = ?
#
# with parameters: ['Tmem261']
# No results found for query:
#
#             SELECT distinct gene_id
#             FROM gene
#             WHERE gene_name = ?
#
# with parameters: ['Tmem27']
# No results found for query:
#
#             SELECT distinct gene_id
#             FROM gene
#             WHERE gene_name = ?
#
# with parameters: ['Tmem35']
# No results found for query:
#
#             SELECT distinct gene_id
#             FROM gene
#             WHERE gene_name = ?
#
# with parameters: ['Tmem5']
# No results found for query:
#
#             SELECT distinct gene_id
#             FROM gene
#             WHERE gene_name = ?
#
# with parameters: ['Tmem55a']
# No results found for query:
#
#             SELECT distinct gene_id
#             FROM gene
#             WHERE gene_name = ?
#
# with parameters: ['Tmem55b']
# No results found for query:
#
#             SELECT distinct gene_id
#             FROM gene
#             WHERE gene_name = ?
#
# with parameters: ['Tmem56']
# No results found for query:
#
#             SELECT distinct gene_id
#             FROM gene
#             WHERE gene_name = ?
#
# with parameters: ['Tmem57']
# No results found for query:
#
#             SELECT distinct gene_id
#             FROM gene
#             WHERE gene_name = ?
#
# with parameters: ['Tmem8c']
# No results found for query:
#
#             SELECT distinct gene_id
#             FROM gene
#             WHERE gene_name = ?
#
# with parameters: ['Toporsos']
# No results found for query:
#
#             SELECT distinct gene_id
#             FROM gene
#             WHERE gene_name = ?
#
# with parameters: ['Trove2']
# No results found for query:
#
#             SELECT distinct gene_id
#             FROM gene
#             WHERE gene_name = ?
#
# with parameters: ['Tssc1']
# No results found for query:
#
#             SELECT distinct gene_id
#             FROM gene
#             WHERE gene_name = ?
#
# with parameters: ['Tusc5']
# No results found for query:
#
#             SELECT distinct gene_id
#             FROM gene
#             WHERE gene_name = ?
#
# with parameters: ['Vimp']
# No results found for query:
#
#             SELECT distinct gene_id
#             FROM gene
#             WHERE gene_name = ?
#
# with parameters: ['Vprbp']
# No results found for query:
#
#             SELECT distinct gene_id
#             FROM gene
#             WHERE gene_name = ?
#
# with parameters: ['Vwa9']
# No results found for query:
#
#             SELECT distinct gene_id
#             FROM gene
#             WHERE gene_name = ?
#
# with parameters: ['WDR97']
# No results found for query:
#
#             SELECT distinct gene_id
#             FROM gene
#             WHERE gene_name = ?
#
# with parameters: ['WI1-2587D24']
# No results found for query:
#
#             SELECT distinct gene_id
#             FROM gene
#             WHERE gene_name = ?
#
# with parameters: ['Wash1']
# No results found for query:
#
#             SELECT distinct gene_id
#             FROM gene
#             WHERE gene_name = ?
#
# with parameters: ['Wbp5']
# No results found for query:
#
#             SELECT distinct gene_id
#             FROM gene
#             WHERE gene_name = ?
#
# with parameters: ['Wbscr16']
# No results found for query:
#
#             SELECT distinct gene_id
#             FROM gene
#             WHERE gene_name = ?
#
# with parameters: ['Wbscr17']
# No results found for query:
#
#             SELECT distinct gene_id
#             FROM gene
#             WHERE gene_name = ?
#
# with parameters: ['Wbscr22']
# No results found for query:
#
#             SELECT distinct gene_id
#             FROM gene
#             WHERE gene_name = ?
#
# with parameters: ['Wbscr27']
# No results found for query:
#
#             SELECT distinct gene_id
#             FROM gene
#             WHERE gene_name = ?
#
# with parameters: ['Wbscr28']
# No results found for query:
#
#             SELECT distinct gene_id
#             FROM gene
#             WHERE gene_name = ?
#
# with parameters: ['Whsc1']
# No results found for query:
#
#             SELECT distinct gene_id
#             FROM gene
#             WHERE gene_name = ?
#
# with parameters: ['Whsc1l1']
# No results found for query:
#
#             SELECT distinct gene_id
#             FROM gene
#             WHERE gene_name = ?
#
# with parameters: ['Wisp1']
# No results found for query:
#
#             SELECT distinct gene_id
#             FROM gene
#             WHERE gene_name = ?
#
# with parameters: ['Wisp2']
# No results found for query:
#
#             SELECT distinct gene_id
#             FROM gene
#             WHERE gene_name = ?
#
# with parameters: ['Wisp3']
# No results found for query:
#
#             SELECT distinct gene_id
#             FROM gene
#             WHERE gene_name = ?
#
# with parameters: ['Wrb']
# No results found for query:
#
#             SELECT distinct gene_id
#             FROM gene
#             WHERE gene_name = ?
#
# with parameters: ['Xrcc6bp1']
# No results found for query:
#
#             SELECT distinct gene_id
#             FROM gene
#             WHERE gene_name = ?
#
# with parameters: ['Zak']
# No results found for query:
#
#             SELECT distinct gene_id
#             FROM gene
#             WHERE gene_name = ?
#
# with parameters: ['Zcchc11']
# No results found for query:
#
#             SELECT distinct gene_id
#             FROM gene
#             WHERE gene_name = ?
#
# with parameters: ['Zcchc16']
# No results found for query:
#
#             SELECT distinct gene_id
#             FROM gene
#             WHERE gene_name = ?
#
# with parameters: ['Zcchc5']
# No results found for query:
#
#             SELECT distinct gene_id
#             FROM gene
#             WHERE gene_name = ?
#
# with parameters: ['Zcchc6']
# No results found for query:
#
#             SELECT distinct gene_id
#             FROM gene
#             WHERE gene_name = ?
#
# with parameters: ['Zfos1']
# No results found for query:
#
#             SELECT distinct gene_id
#             FROM gene
#             WHERE gene_name = ?
#
# with parameters: ['Zfp607']
# No results found for query:
#
#             SELECT distinct gene_id
#             FROM gene
#             WHERE gene_name = ?
#
# with parameters: ['Zufsp']
# No results found for query:
#
#             SELECT distinct gene_id
#             FROM gene
#             WHERE gene_name = ?
#
# with parameters: ['l7Rn6']

# %%
adata.var.head()
# Out:
#               gene_short_name  n_counts    chr        start          end  \
# 0610007P14Rik   0610007P14Rik     485.0    NaN          NaN          NaN
# 0610009B22Rik   0610009B22Rik     133.0  chr11   51685386.0   51688874.0
# 0610009L18Rik   0610009L18Rik      53.0  chr11  120348678.0  120351190.0
# 0610009O20Rik   0610009O20Rik     750.0    NaN          NaN          NaN
# 0610010F05Rik   0610010F05Rik    1570.0  chr11   23564961.0   23633639.0
#
#               strand
# 0610007P14Rik    NaN
# 0610009B22Rik      -
# 0610009L18Rik      +
# 0610009O20Rik    NaN
# 0610010F05Rik      -

# %%
adata.shape, adata.obsm['mode2'].shape
# Out:
# ((34774, 23076), (34774, 344592))

# %%
# basic quality control
adata = _filter_has_chr(adata)
adata = _filter_mitochondrial(adata)
adata = _filter_n_genes_max(adata)
adata = _filter_n_genes_min(adata)
adata = _filter_n_cells(adata)

# %%
adata.shape, adata.obsm['mode2'].shape
# Out:
# ((33827, 18671), (33827, 344592))

# %% [markdown]
# ## Normalize

# %%
sc.pp.normalize_total(adata, target_sum=1e4)
sc.pp.log1p(adata)

# %% [markdown]
# # (Joint) Feature selection
#
# * currently selected by top 2000 variable genes

# %%
if 2000 <= adata.shape[1]:
    sc.pp.highly_variable_genes(adata, n_top_genes=2000)
    adata = adata[:, adata.var.highly_variable].copy()

# %%
# generate peak to gene weight matrix
# remove genes without annotation
adata = adata[
    :, adata.var.loc[:, "chr"].isin(np.unique(adata.uns["mode2_var_chr"]))
].copy()

# %%
adata.shape, adata.obsm['mode2'].shape
# Out:
# ((33827, 1994), (33827, 344592))

# %% [markdown]
# # Regulatory effect score

# %%
# filter atac-seq matrix
sel = np.isin(adata.uns["mode2_var_chr"], adata.var.loc[:, "chr"].unique())
adata.uns["mode2_var"] = adata.uns["mode2_var"][sel]
adata.uns["mode2_var_chr"] = adata.uns["mode2_var_chr"][sel]
adata.uns["mode2_var_start"] = adata.uns["mode2_var_start"][sel]
adata.uns["mode2_var_end"] = adata.uns["mode2_var_end"][sel]
adata.obsm["mode2"] = adata.obsm["mode2"][:, sel]

# %%
adata.shape, adata.obsm['mode2'].shape
# Out:
# ((33827, 1994), (33827, 344592))

# %%
# extend tss upstream and downstream
extend_tss = adata.var.loc[:, ["start", "end", "strand"]].apply(
    _chrom_limit, axis=1
)
extend_tss.shape
# Out:
# (1994,)

# %%
if isinstance(extend_tss, pd.DataFrame):
    # should be a series
    extend_tss = extend_tss.iloc[:, 0]

extend_tss = pd.concat(
    [
        adata.var.loc[:, "chr"],
        extend_tss.map(lambda x: x[0]).astype("int32"),
        extend_tss.map(lambda x: x[1]).astype("int32"),
        pd.Series(np.arange(adata.shape[1]), index=adata.var_names),
    ],
    axis=1,
)

# %%
(extend_tss.iloc[:, 1]>0).sum(), (extend_tss.iloc[:, 2]>0).sum()
# Out:
# (1994, 1994)

# %%
# peak summits
peaks = pd.DataFrame(
    {
        "chr": adata.uns["mode2_var_chr"],
        "start": adata.uns["mode2_var_start"].astype("int32"),
        "end": adata.uns["mode2_var_end"].astype("int32"),
    }
)
summits = pd.concat(
    [
        peaks.iloc[:, 0],
        peaks.iloc[:, [1, 2]].mean(axis=1).astype("int32"),
        (peaks.iloc[:, [1, 2]].mean(axis=1) + 1).astype("int32"),
        pd.Series(np.arange(peaks.shape[0])),
    ],
    axis=1,
)

# %%
peaks.shape, summits.shape
# Out:
# ((344592, 3), (344592, 4))

# %% [markdown]
# ## Intersection between peak and TSS(+/- 100kb)

# %%
import pybedtools

# overlap TSS bins with peaks
x = pybedtools.BedTool.from_dataframe(summits)
y = pybedtools.BedTool.from_dataframe(extend_tss)

# %%
#tss_to_peaks = y.intersect(x, wb=True, wa=True, loj=False).to_dataframe()
tss_to_peaks = x.intersect(y, wb=True, wa=True, loj=True)
# Out:
# /Users/qq06/anaconda3/envs/openproblem/lib/python3.8/subprocess.py:849: RuntimeWarning: line buffering (buffering=1) isn't supported in binary mode, the default buffer size will be used
#   self.stderr = io.open(errread, 'rb', bufsize)

# %%
tss_to_peaks = tss_to_peaks.to_dataframe(disable_auto_names=True, header=0,
                                         names=["peak_chr", 
                                                 "peak_summit_left",
                                                 "peak_summit_right", 
                                                 "peak_index", 
                                                 "gene_chr", 
                                                 "gene_bin_start", 
                                                 "gene_bin_end", 
                                                 "gene_index"])
print(tss_to_peaks.shape)
# Out:
# (362657, 8)

# %%
tss_to_peaks.head()
# Out:
#   peak_chr  peak_summit_left  peak_summit_right  peak_index gene_chr  \
# 0     chr6           3201126            3201127           1        .
# 1     chr9         123462000          123462001           2     chr9
# 2     chr1          56782245           56782246           3        .
# 3     chr9          56223818           56223819           4        .
# 4     chr1          88277609           88277610           5        .
#
#    gene_bin_start  gene_bin_end gene_index
# 0              -1            -1          .
# 1       123266927     123466927       1203
# 2              -1            -1          .
# 3              -1            -1          .
# 4              -1            -1          .

# %%
# remove non-overlapped TSS and peaks
tss_to_peaks = tss_to_peaks.loc[
    (tss_to_peaks.gene_chr != ".") | (tss_to_peaks.gene_index != "."), :
]

# %%
tss_to_peaks.shape, (tss_to_peaks.iloc[:, 1] >0).sum(), (tss_to_peaks.iloc[:, 2] >0).sum()
# Out:
# ((97429, 8), 97429, 97429)

# %%
tss_to_peaks.shape, (tss_to_peaks.iloc[:, 5] >0).sum(), (tss_to_peaks.iloc[:, 6] >0).sum()
# Out:
# ((97429, 8), 97429, 97429)

# %%
tss_to_peaks.apply(
    lambda x: abs((int(x[5]) + int(x[6])) / 2 - int(x[1])) * 1.0 / 1e5, axis=1
).values
# Out:
# array([0.95073, 0.87698, 0.29745, ..., 0.0534 , 0.90248, 0.763  ])

# %%
tss_to_peaks.shape
# Out:
# (97429, 8)

# %% [markdown]
# ## Peak to gene distance weighted by MARGE

# %%
tss_to_peaks.loc[:, "distance"] = tss_to_peaks.apply(
    lambda x: abs((int(x[5]) + int(x[6])) / 2 - int(x[1])) * 1.0 / 1e5, axis=1
)

# %%
alpha = -np.log(1.0 / 3.0) * 1e5 / 1e4
alpha
# Out:
# 10.986122886681098

# %%
decay_score = np.exp(-alpha * tss_to_peaks["distance"].values)
tss_to_peaks["weight"] = 2.0 * decay_score / (1.0 + decay_score)

# %%
tss_to_peaks["weight"].shape
# Out:
# (97429,)

# %%
(tss_to_peaks["weight"]>0.9).sum()
# Out:
# 5141

# %%
import scipy
gene_peak_weight = scipy.sparse.csr_matrix(
    (
        tss_to_peaks.weight.values,
        (tss_to_peaks.gene_index.astype("int32").values, tss_to_peaks.peak_index),
    ),
    shape=(adata.shape[1], adata.uns["mode2_var"].shape[0]),
)

# %%
adata.obsm["gene_score"] = adata.obsm["mode2"] @ gene_peak_weight.T

# %% [markdown]
# # Imputation of single cell RNA-seq

# %%
import scanpy as sc

# %%
sc.pp.pca(adata)

# %%
sc.pp.neighbors(adata, n_neighbors=300)

# %%
adata.layers['X_knn'] = adata.obsp['connectivities'].dot(adata.X)

# %% [markdown]
# # Imputatation of single cell ATAC-seq

# %%
adata.layers['gene_score_knn'] = adata.obsp['connectivities'].dot(adata.obsm["gene_score"])

# %% [markdown]
# # Metrics

# %% [markdown]
# ## Across genes

# %%
def compute_similarity2(O, P):
    "Compute pearson correlation between two matrices O and P using einstein summation"
    (n, t) = O.shape      # n traces of t samples
    (n_bis, m) = P.shape  # n predictions for each of m candidates

    DO = O - (np.einsum("nt->t", O, optimize='optimal') / np.double(n)) # compute O - mean(O)
    DP = P - (np.einsum("nm->m", P, optimize='optimal') / np.double(n)) # compute P - mean(P)

    cov = np.einsum("nm,nt->mt", DP, DO, optimize='optimal')

    varP = np.einsum("nm,nm->m", DP, DP, optimize='optimal')
    varO = np.einsum("nt,nt->t", DO, DO, optimize='optimal')
    tmp = np.einsum("m,t->mt", varP, varO, optimize='optimal')
    return cov / np.sqrt(tmp)

# %%
cors = compute_similarity2(adata.layers['X_knn'].toarray(), adata.layers['gene_score_knn'].toarray())
# Out:
# <ipython-input-57-3519e1864505>:14: RuntimeWarning: invalid value encountered in true_divide
#   return cov / np.sqrt(tmp)

# %%
np.median(cors[~np.isnan(cors)])
# Out:
# 0.07538634116228767

# %%
cors_diag = np.diag(cors)
np.median(cors_diag[~np.isnan(cors_diag)])
# Out:
# 0.14733736751645934

# %% [markdown]
# ## Across pseudo-bulk cell aggregates by KNN

# %%
cors = compute_similarity2(adata.layers['X_knn'].toarray().T[:, :10000], 
                           adata.layers['gene_score_knn'].toarray().T[:, :10000])

# %%
np.median(cors[~np.isnan(cors)])
# Out:
# 0.13612813178507155

# %%
cors_diag = np.diag(cors)
np.median(cors_diag[~np.isnan(cors_diag)])
# Out:
# 0.18688686100935356

# %% [markdown]
# ## Global correlation

# %%
def _global_pearson(x, y):
    numerator = np.mean((x - x.mean()) * (y - y.mean()))
    denominator = x.std() * y.std()
    if denominator == 0:
        return 0
    else:
        result = numerator / denominator
        return result

# %%
_global_pearson(adata.layers['X_knn'].toarray(),
                adata.layers['gene_score_knn'].toarray())
# Out:
# 0.2139866102030402
