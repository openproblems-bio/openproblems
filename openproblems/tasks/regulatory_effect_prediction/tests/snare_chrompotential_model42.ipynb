# %%
# %load_ext autoreload
# %autoreload 2

# %% [markdown]
# # Step loading data

# %%
import pandas as pd
import numpy as np
from openproblems.tasks.regulatory_effect_prediction import datasets
adata = datasets.snare_p0_braincortex(test=False)

# %%
adata.uns['mode2_var_chr'].shape, adata.uns['mode2_var'].shape
# Out:
# ((229429,), (229429, 3))

# %%
adata.shape, adata.obsm['mode2'].shape
# Out:
# ((5081, 19322), (5081, 229429))

# %% [markdown]
# ## Copy of utility functions

# %%
from openproblems.patch import patch_datacache
import numpy as np
import pandas as pd
import scanpy as sc
import warnings

def _chrom_limit(x, tss_size=2e5):
    """Extend TSS to upstream and downstream intervals.

    Parameters
    ----------
    x : pd.Series
        a pd.Series containing [start, end, direction]
        where start and end are ints and direction is {'+', '-'}.
    tss_size: int
        a int that defines the upstream and downstream regions around TSS
    """
    y = x.values
    gene_direction = y[-1]
    gene_start = y[-3]
    gene_end = y[-2]
    if gene_direction == "+":
        return [gene_start - tss_size // 2, gene_start + tss_size // 2]
    else:
        return [gene_end - tss_size // 2, gene_end + tss_size // 2]


def _get_annotation(adata, retries=3):
    """Insert meta data into adata.obs."""
    from pyensembl import EnsemblRelease

    data = EnsemblRelease(
        adata.uns["release"],
        adata.uns["species"],
    )
    for _ in range(retries):
        try:
            with patch_datacache():
                data.download(overwrite=False)
                data.index(overwrite=False)
            break
        except TimeoutError:
            pass

    # get ensemble gene coordinate
    genes = []
    for i in adata.var.index.map(lambda x: x.split(".")[0]):
        try:
            with warnings.catch_warnings():
                warnings.filterwarnings(
                    action="ignore", message="No results found for query"
                )
                gene = data.gene_by_id(i)
            genes.append(
                [
                    "chr%s" % gene.contig,
                    gene.start,
                    gene.end,
                    gene.strand,
                    gene.exons
                ]
            )
        except ValueError:
            try:
                with warnings.catch_warnings():
                    warnings.filterwarnings(
                        action="ignore", message="No results found for query"
                    )
                    i = data.gene_ids_of_gene_name(i)[0]
                gene = data.gene_by_id(i)
                genes.append(
                    [
                        "chr%s" % gene.contig,
                        gene.start,
                        gene.end,
                        gene.strand,
                        gene.exons                        
                    ]
                )
            except (IndexError, ValueError) as e:
                print(e)
                genes.append([np.nan, np.nan, np.nan, np.nan])
    old_col = adata.var.columns.values
    adata.var = pd.concat(
        [adata.var, pd.DataFrame(genes, index=adata.var_names)], axis=1
    )
    adata.var.columns = np.hstack(
        [old_col, np.array(["chr", "start", "end", "strand"])]
    )


def _filter_mitochondrial(adata):
    if adata.uns["species"] in ["mus_musculus", "homo_sapiens"]:
        adata.var["mt"] = adata.var.gene_short_name.str.lower().str.startswith(
            "mt-"
        )  # annotate the group of mitochondrial genes as 'mt'
        sc.pp.calculate_qc_metrics(
            adata, qc_vars=["mt"], percent_top=None, log1p=False, inplace=True
        )

        adata_filter = adata[adata.obs.pct_counts_mt <= 10]
        if adata_filter.shape[0] > 100:
            adata = adata_filter.copy()
    return adata


def _filter_n_genes_max(adata):
    adata_filter = adata[adata.obs.n_genes_by_counts <= 2000]
    if adata_filter.shape[0] > 100:
        adata = adata_filter.copy()
    return adata


def _filter_n_genes_min(adata):
    adata_filter = adata.copy()
    sc.pp.filter_cells(adata_filter, min_genes=200)
    if adata_filter.shape[0] > 100:
        adata = adata_filter
    return adata


def _filter_n_cells(adata):
    adata_filter = adata.copy()
    sc.pp.filter_genes(adata_filter, min_cells=5)
    if adata_filter.shape[1] > 100:
        adata = adata_filter
    return adata


def _filter_has_chr(adata):
    adata_filter = adata[:, ~pd.isnull(adata.var.loc[:, "chr"])].copy()
    if adata_filter.shape[1] > 100:
        adata = adata_filter
    return adata

# %% [markdown]
# ## Get gene coordinates

# %%
adata.var.tail()
# Out:
#          gene_short_name  n_counts
# genes
# Vsig4              Vsig4       1.0
# Zfp296            Zfp296       1.0
# Zpld1              Zpld1       1.0
# mt-Ta              mt-Ta       1.0
# n-R5s158        n-R5s158       1.0

# %%
_get_annotation(adata)
# Out:
# No results found for query:
#
#             SELECT distinct gene_id
#             FROM gene
#             WHERE gene_name = ?
#
# with parameters: ['0610007P14Rik']
# No results found for query:
#
#             SELECT distinct gene_id
#             FROM gene
#             WHERE gene_name = ?
#
# with parameters: ['0610009O20Rik']
# No results found for query:
#
#             SELECT distinct gene_id
#             FROM gene
#             WHERE gene_name = ?
#
# with parameters: ['0610037L13Rik']
# No results found for query:
#
#             SELECT distinct gene_id
#             FROM gene
#             WHERE gene_name = ?
#
# with parameters: ['1110001J03Rik']
# No results found for query:
#
#             SELECT distinct gene_id
#             FROM gene
#             WHERE gene_name = ?
#
# with parameters: ['1110004E09Rik']
# No results found for query:
#
#             SELECT distinct gene_id
#             FROM gene
#             WHERE gene_name = ?
#
# with parameters: ['1110007C09Rik']
# No results found for query:
#
#             SELECT distinct gene_id
#             FROM gene
#             WHERE gene_name = ?
#
# with parameters: ['1110008F13Rik']
# No results found for query:
#
#             SELECT distinct gene_id
#             FROM gene
#             WHERE gene_name = ?
#
# with parameters: ['1110008L16Rik']
# No results found for query:
#
#             SELECT distinct gene_id
#             FROM gene
#             WHERE gene_name = ?
#
# with parameters: ['1110034G24Rik']
# No results found for query:
#
#             SELECT distinct gene_id
#             FROM gene
#             WHERE gene_name = ?
#
# with parameters: ['1110037F02Rik']
# No results found for query:
#
#             SELECT distinct gene_id
#             FROM gene
#             WHERE gene_name = ?
#
# with parameters: ['1190002F15Rik']
# No results found for query:
#
#             SELECT distinct gene_id
#             FROM gene
#             WHERE gene_name = ?
#
# with parameters: ['1190002N15Rik']
# No results found for query:
#
#             SELECT distinct gene_id
#             FROM gene
#             WHERE gene_name = ?
#
# with parameters: ['1200014J11Rik']
# No results found for query:
#
#             SELECT distinct gene_id
#             FROM gene
#             WHERE gene_name = ?
#
# with parameters: ['1500011K16Rik']
# No results found for query:
#
#             SELECT distinct gene_id
#             FROM gene
#             WHERE gene_name = ?
#
# with parameters: ['1500012F01Rik']
# No results found for query:
#
#             SELECT distinct gene_id
#             FROM gene
#             WHERE gene_name = ?
#
# with parameters: ['1500015O10Rik']
# No results found for query:
#
#             SELECT distinct gene_id
#             FROM gene
#             WHERE gene_name = ?
#
# with parameters: ['1500017E21Rik']
# No results found for query:
#
#             SELECT distinct gene_id
#             FROM gene
#             WHERE gene_name = ?
#
# with parameters: ['1600002H07Rik']
# No results found for query:
#
#             SELECT distinct gene_id
#             FROM gene
#             WHERE gene_name = ?
#
# with parameters: ['1600002K03Rik']
# No results found for query:
#
#             SELECT distinct gene_id
#             FROM gene
#             WHERE gene_name = ?
#
# with parameters: ['1700007B14Rik']
# No results found for query:
#
#             SELECT distinct gene_id
#             FROM gene
#             WHERE gene_name = ?
#
# with parameters: ['1700007G11Rik']
# No results found for query:
#
#             SELECT distinct gene_id
#             FROM gene
#             WHERE gene_name = ?
#
# with parameters: ['1700011I03Rik']
# No results found for query:
#
#             SELECT distinct gene_id
#             FROM gene
#             WHERE gene_name = ?
#
# with parameters: ['1700019L03Rik']
# No results found for query:
#
#             SELECT distinct gene_id
#             FROM gene
#             WHERE gene_name = ?
#
# with parameters: ['1700020I14Rik']
# No results found for query:
#
#             SELECT distinct gene_id
#             FROM gene
#             WHERE gene_name = ?
#
# with parameters: ['1700021F05Rik']
# No results found for query:
#
#             SELECT distinct gene_id
#             FROM gene
#             WHERE gene_name = ?
#
# with parameters: ['1700021K19Rik']
# No results found for query:
#
#             SELECT distinct gene_id
#             FROM gene
#             WHERE gene_name = ?
#
# with parameters: ['1700024P16Rik']
# No results found for query:
#
#             SELECT distinct gene_id
#             FROM gene
#             WHERE gene_name = ?
#
# with parameters: ['1700026D08Rik']
# No results found for query:
#
#             SELECT distinct gene_id
#             FROM gene
#             WHERE gene_name = ?
#
# with parameters: ['1700026L06Rik']
# No results found for query:
#
#             SELECT distinct gene_id
#             FROM gene
#             WHERE gene_name = ?
#
# with parameters: ['1700027J19Rik']
# No results found for query:
#
#             SELECT distinct gene_id
#             FROM gene
#             WHERE gene_name = ?
#
# with parameters: ['1700040L02Rik']
# No results found for query:
#
#             SELECT distinct gene_id
#             FROM gene
#             WHERE gene_name = ?
#
# with parameters: ['1700049G17Rik']
# No results found for query:
#
#             SELECT distinct gene_id
#             FROM gene
#             WHERE gene_name = ?
#
# with parameters: ['1700061G19Rik']
# No results found for query:
#
#             SELECT distinct gene_id
#             FROM gene
#             WHERE gene_name = ?
#
# with parameters: ['1700080G11Rik']
# No results found for query:
#
#             SELECT distinct gene_id
#             FROM gene
#             WHERE gene_name = ?
#
# with parameters: ['1700084C01Rik']
# No results found for query:
#
#             SELECT distinct gene_id
#             FROM gene
#             WHERE gene_name = ?
#
# with parameters: ['1700112E06Rik']
# No results found for query:
#
#             SELECT distinct gene_id
#             FROM gene
#             WHERE gene_name = ?
#
# with parameters: ['1810011O10Rik']
# No results found for query:
#
#             SELECT distinct gene_id
#             FROM gene
#             WHERE gene_name = ?
#
# with parameters: ['1810022K09Rik']
# No results found for query:
#
#             SELECT distinct gene_id
#             FROM gene
#             WHERE gene_name = ?
#
# with parameters: ['1810026J23Rik']
# No results found for query:
#
#             SELECT distinct gene_id
#             FROM gene
#             WHERE gene_name = ?
#
# with parameters: ['1810032O08Rik']
# No results found for query:
#
#             SELECT distinct gene_id
#             FROM gene
#             WHERE gene_name = ?
#
# with parameters: ['1810041L15Rik']
# No results found for query:
#
#             SELECT distinct gene_id
#             FROM gene
#             WHERE gene_name = ?
#
# with parameters: ['1810043G02Rik']
# No results found for query:
#
#             SELECT distinct gene_id
#             FROM gene
#             WHERE gene_name = ?
#
# with parameters: ['1810043H04Rik']
# No results found for query:
#
#             SELECT distinct gene_id
#             FROM gene
#             WHERE gene_name = ?
#
# with parameters: ['2010107E04Rik']
# No results found for query:
#
#             SELECT distinct gene_id
#             FROM gene
#             WHERE gene_name = ?
#
# with parameters: ['2010107G12Rik']
# No results found for query:
#
#             SELECT distinct gene_id
#             FROM gene
#             WHERE gene_name = ?
#
# with parameters: ['2010107G23Rik']
# No results found for query:
#
#             SELECT distinct gene_id
#             FROM gene
#             WHERE gene_name = ?
#
# with parameters: ['2010111I01Rik']
# No results found for query:
#
#             SELECT distinct gene_id
#             FROM gene
#             WHERE gene_name = ?
#
# with parameters: ['2210008F06Rik']
# No results found for query:
#
#             SELECT distinct gene_id
#             FROM gene
#             WHERE gene_name = ?
#
# with parameters: ['2210013O21Rik']
# No results found for query:
#
#             SELECT distinct gene_id
#             FROM gene
#             WHERE gene_name = ?
#
# with parameters: ['2210018M11Rik']
# No results found for query:
#
#             SELECT distinct gene_id
#             FROM gene
#             WHERE gene_name = ?
#
# with parameters: ['2210404O09Rik']
# No results found for query:
#
#             SELECT distinct gene_id
#             FROM gene
#             WHERE gene_name = ?
#
# with parameters: ['2310009A05Rik']
# No results found for query:
#
#             SELECT distinct gene_id
#             FROM gene
#             WHERE gene_name = ?
#
# with parameters: ['2310010G23Rik']
# No results found for query:
#
#             SELECT distinct gene_id
#             FROM gene
#             WHERE gene_name = ?
#
# with parameters: ['2310031A07Rik']
# No results found for query:
#
#             SELECT distinct gene_id
#             FROM gene
#             WHERE gene_name = ?
#
# with parameters: ['2310035C23Rik']
# No results found for query:
#
#             SELECT distinct gene_id
#             FROM gene
#             WHERE gene_name = ?
#
# with parameters: ['2310036O22Rik']
# No results found for query:
#
#             SELECT distinct gene_id
#             FROM gene
#             WHERE gene_name = ?
#
# with parameters: ['2310067B10Rik']
# No results found for query:
#
#             SELECT distinct gene_id
#             FROM gene
#             WHERE gene_name = ?
#
# with parameters: ['2310069G16Rik']
# No results found for query:
#
#             SELECT distinct gene_id
#             FROM gene
#             WHERE gene_name = ?
#
# with parameters: ['2410015M20Rik']
# No results found for query:
#
#             SELECT distinct gene_id
#             FROM gene
#             WHERE gene_name = ?
#
# with parameters: ['2410016O06Rik']
# No results found for query:
#
#             SELECT distinct gene_id
#             FROM gene
#             WHERE gene_name = ?
#
# with parameters: ['2410089E03Rik']
# No results found for query:
#
#             SELECT distinct gene_id
#             FROM gene
#             WHERE gene_name = ?
#
# with parameters: ['2610015P09Rik']
# No results found for query:
#
#             SELECT distinct gene_id
#             FROM gene
#             WHERE gene_name = ?
#
# with parameters: ['2610020H08Rik']
# No results found for query:
#
#             SELECT distinct gene_id
#             FROM gene
#             WHERE gene_name = ?
#
# with parameters: ['2610203C20Rik']
# No results found for query:
#
#             SELECT distinct gene_id
#             FROM gene
#             WHERE gene_name = ?
#
# with parameters: ['2610305D13Rik']
# No results found for query:
#
#             SELECT distinct gene_id
#             FROM gene
#             WHERE gene_name = ?
#
# with parameters: ['2700016F22Rik']
# No results found for query:
#
#             SELECT distinct gene_id
#             FROM gene
#             WHERE gene_name = ?
#
# with parameters: ['2700029M09Rik']
# No results found for query:
#
#             SELECT distinct gene_id
#             FROM gene
#             WHERE gene_name = ?
#
# with parameters: ['2700060E02Rik']
# No results found for query:
#
#             SELECT distinct gene_id
#             FROM gene
#             WHERE gene_name = ?
#
# with parameters: ['2810403A07Rik']
# No results found for query:
#
#             SELECT distinct gene_id
#             FROM gene
#             WHERE gene_name = ?
#
# with parameters: ['2810417H13Rik']
# No results found for query:
#
#             SELECT distinct gene_id
#             FROM gene
#             WHERE gene_name = ?
#
# with parameters: ['2810425M01Rik']
# No results found for query:
#
#             SELECT distinct gene_id
#             FROM gene
#             WHERE gene_name = ?
#
# with parameters: ['2810428I15Rik']
# No results found for query:
#
#             SELECT distinct gene_id
#             FROM gene
#             WHERE gene_name = ?
#
# with parameters: ['2810468N07Rik']
# No results found for query:
#
#             SELECT distinct gene_id
#             FROM gene
#             WHERE gene_name = ?
#
# with parameters: ['2810474O19Rik']
# No results found for query:
#
#             SELECT distinct gene_id
#             FROM gene
#             WHERE gene_name = ?
#
# with parameters: ['2900011O08Rik']
# No results found for query:
#
#             SELECT distinct gene_id
#             FROM gene
#             WHERE gene_name = ?
#
# with parameters: ['2900055J20Rik']
# No results found for query:
#
#             SELECT distinct gene_id
#             FROM gene
#             WHERE gene_name = ?
#
# with parameters: ['3010026O09Rik']
# No results found for query:
#
#             SELECT distinct gene_id
#             FROM gene
#             WHERE gene_name = ?
#
# with parameters: ['3110002H16Rik']
# No results found for query:
#
#             SELECT distinct gene_id
#             FROM gene
#             WHERE gene_name = ?
#
# with parameters: ['3110035E14Rik']
# No results found for query:
#
#             SELECT distinct gene_id
#             FROM gene
#             WHERE gene_name = ?
#
# with parameters: ['3110043O21Rik']
# No results found for query:
#
#             SELECT distinct gene_id
#             FROM gene
#             WHERE gene_name = ?
#
# with parameters: ['3110052M02Rik']
# No results found for query:
#
#             SELECT distinct gene_id
#             FROM gene
#             WHERE gene_name = ?
#
# with parameters: ['3110057O12Rik']
# No results found for query:
#
#             SELECT distinct gene_id
#             FROM gene
#             WHERE gene_name = ?
#
# with parameters: ['3110062M04Rik']
# No results found for query:
#
#             SELECT distinct gene_id
#             FROM gene
#             WHERE gene_name = ?
#
# with parameters: ['3632451O06Rik']
# No results found for query:
#
#             SELECT distinct gene_id
#             FROM gene
#             WHERE gene_name = ?
#
# with parameters: ['4632428N05Rik']
# No results found for query:
#
#             SELECT distinct gene_id
#             FROM gene
#             WHERE gene_name = ?
#
# with parameters: ['4831440E17Rik']
# No results found for query:
#
#             SELECT distinct gene_id
#             FROM gene
#             WHERE gene_name = ?
#
# with parameters: ['4921506M07Rik']
# No results found for query:
#
#             SELECT distinct gene_id
#             FROM gene
#             WHERE gene_name = ?
#
# with parameters: ['4921507L20Rik']
# No results found for query:
#
#             SELECT distinct gene_id
#             FROM gene
#             WHERE gene_name = ?
#
# with parameters: ['4930415F15Rik']
# No results found for query:
#
#             SELECT distinct gene_id
#             FROM gene
#             WHERE gene_name = ?
#
# with parameters: ['4930427A07Rik']
# No results found for query:
#
#             SELECT distinct gene_id
#             FROM gene
#             WHERE gene_name = ?
#
# with parameters: ['4930448N21Rik']
# No results found for query:
#
#             SELECT distinct gene_id
#             FROM gene
#             WHERE gene_name = ?
#
# with parameters: ['4930469G21Rik']
# No results found for query:
#
#             SELECT distinct gene_id
#             FROM gene
#             WHERE gene_name = ?
#
# with parameters: ['4930480K23Rik']
# No results found for query:
#
#             SELECT distinct gene_id
#             FROM gene
#             WHERE gene_name = ?
#
# with parameters: ['4930524J08Rik']
# No results found for query:
#
#             SELECT distinct gene_id
#             FROM gene
#             WHERE gene_name = ?
#
# with parameters: ['4930533O14Rik']
# No results found for query:
#
#             SELECT distinct gene_id
#             FROM gene
#             WHERE gene_name = ?
#
# with parameters: ['4930578C19Rik']
# No results found for query:
#
#             SELECT distinct gene_id
#             FROM gene
#             WHERE gene_name = ?
#
# with parameters: ['4930598A11Rik']
# No results found for query:
#
#             SELECT distinct gene_id
#             FROM gene
#             WHERE gene_name = ?
#
# with parameters: ['4931409K22Rik']
# No results found for query:
#
#             SELECT distinct gene_id
#             FROM gene
#             WHERE gene_name = ?
#
# with parameters: ['4931423N10Rik']
# No results found for query:
#
#             SELECT distinct gene_id
#             FROM gene
#             WHERE gene_name = ?
#
# with parameters: ['4931440J10Rik']
# No results found for query:
#
#             SELECT distinct gene_id
#             FROM gene
#             WHERE gene_name = ?
#
# with parameters: ['4932443I19Rik']
# No results found for query:
#
#             SELECT distinct gene_id
#             FROM gene
#             WHERE gene_name = ?
#
# with parameters: ['4933408B17Rik']
# No results found for query:
#
#             SELECT distinct gene_id
#             FROM gene
#             WHERE gene_name = ?
#
# with parameters: ['4933427G17Rik']
# No results found for query:
#
#             SELECT distinct gene_id
#             FROM gene
#             WHERE gene_name = ?
#
# with parameters: ['5730508B09Rik']
# No results found for query:
#
#             SELECT distinct gene_id
#             FROM gene
#             WHERE gene_name = ?
#
# with parameters: ['5730559C18Rik']
# No results found for query:
#
#             SELECT distinct gene_id
#             FROM gene
#             WHERE gene_name = ?
#
# with parameters: ['5830415F09Rik']
# No results found for query:
#
#             SELECT distinct gene_id
#             FROM gene
#             WHERE gene_name = ?
#
# with parameters: ['5930422O12Rik']
# No results found for query:
#
#             SELECT distinct gene_id
#             FROM gene
#             WHERE gene_name = ?
#
# with parameters: ['6030419C18Rik']
# No results found for query:
#
#             SELECT distinct gene_id
#             FROM gene
#             WHERE gene_name = ?
#
# with parameters: ['6330403A02Rik']
# No results found for query:
#
#             SELECT distinct gene_id
#             FROM gene
#             WHERE gene_name = ?
#
# with parameters: ['6330408A02Rik']
# No results found for query:
#
#             SELECT distinct gene_id
#             FROM gene
#             WHERE gene_name = ?
#
# with parameters: ['6330416G13Rik']
# No results found for query:
#
#             SELECT distinct gene_id
#             FROM gene
#             WHERE gene_name = ?
#
# with parameters: ['6430531B16Rik']
# No results found for query:
#
#             SELECT distinct gene_id
#             FROM gene
#             WHERE gene_name = ?
#
# with parameters: ['6430573F11Rik']
# No results found for query:
#
#             SELECT distinct gene_id
#             FROM gene
#             WHERE gene_name = ?
#
# with parameters: ['8430408G22Rik']
# No results found for query:
#
#             SELECT distinct gene_id
#             FROM gene
#             WHERE gene_name = ?
#
# with parameters: ['9030617O03Rik']
# No results found for query:
#
#             SELECT distinct gene_id
#             FROM gene
#             WHERE gene_name = ?
#
# with parameters: ['9030624J02Rik']
# No results found for query:
#
#             SELECT distinct gene_id
#             FROM gene
#             WHERE gene_name = ?
#
# with parameters: ['9130011E15Rik']
# No results found for query:
#
#             SELECT distinct gene_id
#             FROM gene
#             WHERE gene_name = ?
#
# with parameters: ['9230110C19Rik']
# No results found for query:
#
#             SELECT distinct gene_id
#             FROM gene
#             WHERE gene_name = ?
#
# with parameters: ['9330132A10Rik']
# No results found for query:
#
#             SELECT distinct gene_id
#             FROM gene
#             WHERE gene_name = ?
#
# with parameters: ['9430016H08Rik']
# No results found for query:
#
#             SELECT distinct gene_id
#             FROM gene
#             WHERE gene_name = ?
#
# with parameters: ['9430020K01Rik']
# No results found for query:
#
#             SELECT distinct gene_id
#             FROM gene
#             WHERE gene_name = ?
#
# with parameters: ['9530027J09Rik']
# No results found for query:
#
#             SELECT distinct gene_id
#             FROM gene
#             WHERE gene_name = ?
#
# with parameters: ['9830147E19Rik']
# No results found for query:
#
#             SELECT distinct gene_id
#             FROM gene
#             WHERE gene_name = ?
#
# with parameters: ['A230046K03Rik']
# No results found for query:
#
#             SELECT distinct gene_id
#             FROM gene
#             WHERE gene_name = ?
#
# with parameters: ['A230050P20Rik']
# No results found for query:
#
#             SELECT distinct gene_id
#             FROM gene
#             WHERE gene_name = ?
#
# with parameters: ['A330017A19Rik']
# No results found for query:
#
#             SELECT distinct gene_id
#             FROM gene
#             WHERE gene_name = ?
#
# with parameters: ['A330069E16Rik']
# No results found for query:
#
#             SELECT distinct gene_id
#             FROM gene
#             WHERE gene_name = ?
#
# with parameters: ['A430046D13Rik']
# No results found for query:
#
#             SELECT distinct gene_id
#             FROM gene
#             WHERE gene_name = ?
#
# with parameters: ['A430105I19Rik']
# No results found for query:
#
#             SELECT distinct gene_id
#             FROM gene
#             WHERE gene_name = ?
#
# with parameters: ['A630033H20Rik']
# No results found for query:
#
#             SELECT distinct gene_id
#             FROM gene
#             WHERE gene_name = ?
#
# with parameters: ['A730017C20Rik']
# No results found for query:
#
#             SELECT distinct gene_id
#             FROM gene
#             WHERE gene_name = ?
#
# with parameters: ['A830010M20Rik']
# No results found for query:
#
#             SELECT distinct gene_id
#             FROM gene
#             WHERE gene_name = ?
#
# with parameters: ['A830080D01Rik']
# No results found for query:
#
#             SELECT distinct gene_id
#             FROM gene
#             WHERE gene_name = ?
#
# with parameters: ['A930011G23Rik']
# No results found for query:
#
#             SELECT distinct gene_id
#             FROM gene
#             WHERE gene_name = ?
#
# with parameters: ['A930024N18Rik']
# No results found for query:
#
#             SELECT distinct gene_id
#             FROM gene
#             WHERE gene_name = ?
#
# with parameters: ['AA415398']
# No results found for query:
#
#             SELECT distinct gene_id
#             FROM gene
#             WHERE gene_name = ?
#
# with parameters: ['AA474331']
# No results found for query:
#
#             SELECT distinct gene_id
#             FROM gene
#             WHERE gene_name = ?
#
# with parameters: ['AA543186']
# No results found for query:
#
#             SELECT distinct gene_id
#             FROM gene
#             WHERE gene_name = ?
#
# with parameters: ['AC156028']
# No results found for query:
#
#             SELECT distinct gene_id
#             FROM gene
#             WHERE gene_name = ?
#
# with parameters: ['AC156028']
# No results found for query:
#
#             SELECT distinct gene_id
#             FROM gene
#             WHERE gene_name = ?
#
# with parameters: ['AF529169']
# No results found for query:
#
#             SELECT distinct gene_id
#             FROM gene
#             WHERE gene_name = ?
#
# with parameters: ['AI118078']
# No results found for query:
#
#             SELECT distinct gene_id
#             FROM gene
#             WHERE gene_name = ?
#
# with parameters: ['AI314180']
# No results found for query:
#
#             SELECT distinct gene_id
#             FROM gene
#             WHERE gene_name = ?
#
# with parameters: ['AI317395']
# No results found for query:
#
#             SELECT distinct gene_id
#             FROM gene
#             WHERE gene_name = ?
#
# with parameters: ['AI464131']
# No results found for query:
#
#             SELECT distinct gene_id
#             FROM gene
#             WHERE gene_name = ?
#
# with parameters: ['AI846148']
# No results found for query:
#
#             SELECT distinct gene_id
#             FROM gene
#             WHERE gene_name = ?
#
# with parameters: ['AI854517']
# No results found for query:
#
#             SELECT distinct gene_id
#             FROM gene
#             WHERE gene_name = ?
#
# with parameters: ['AU019823']
# No results found for query:
#
#             SELECT distinct gene_id
#             FROM gene
#             WHERE gene_name = ?
#
# with parameters: ['Aaed1']
# No results found for query:
#
#             SELECT distinct gene_id
#             FROM gene
#             WHERE gene_name = ?
#
# with parameters: ['Acpt']
# No results found for query:
#
#             SELECT distinct gene_id
#             FROM gene
#             WHERE gene_name = ?
#
# with parameters: ['Adck3']
# No results found for query:
#
#             SELECT distinct gene_id
#             FROM gene
#             WHERE gene_name = ?
#
# with parameters: ['Adck4']
# No results found for query:
#
#             SELECT distinct gene_id
#             FROM gene
#             WHERE gene_name = ?
#
# with parameters: ['Adrbk1']
# No results found for query:
#
#             SELECT distinct gene_id
#             FROM gene
#             WHERE gene_name = ?
#
# with parameters: ['Adrbk2']
# No results found for query:
#
#             SELECT distinct gene_id
#             FROM gene
#             WHERE gene_name = ?
#
# with parameters: ['Aes']
# No results found for query:
#
#             SELECT distinct gene_id
#             FROM gene
#             WHERE gene_name = ?
#
# with parameters: ['Aim1l']
# No results found for query:
#
#             SELECT distinct gene_id
#             FROM gene
#             WHERE gene_name = ?
#
# with parameters: ['Apitd1']
# No results found for query:
#
#             SELECT distinct gene_id
#             FROM gene
#             WHERE gene_name = ?
#
# with parameters: ['Apoa1bp']
# No results found for query:
#
#             SELECT distinct gene_id
#             FROM gene
#             WHERE gene_name = ?
#
# with parameters: ['Asun']
# No results found for query:
#
#             SELECT distinct gene_id
#             FROM gene
#             WHERE gene_name = ?
#
# with parameters: ['Athl1']
# No results found for query:
#
#             SELECT distinct gene_id
#             FROM gene
#             WHERE gene_name = ?
#
# with parameters: ['Atp5f1']
# No results found for query:
#
#             SELECT distinct gene_id
#             FROM gene
#             WHERE gene_name = ?
#
# with parameters: ['Atp5s']
# No results found for query:
#
#             SELECT distinct gene_id
#             FROM gene
#             WHERE gene_name = ?
#
# with parameters: ['Atp5sl']
# No results found for query:
#
#             SELECT distinct gene_id
#             FROM gene
#             WHERE gene_name = ?
#
# with parameters: ['B230344G16Rik']
# No results found for query:
#
#             SELECT distinct gene_id
#             FROM gene
#             WHERE gene_name = ?
#
# with parameters: ['B630005N14Rik']
# No results found for query:
#
#             SELECT distinct gene_id
#             FROM gene
#             WHERE gene_name = ?
#
# with parameters: ['BC003331']
# No results found for query:
#
#             SELECT distinct gene_id
#             FROM gene
#             WHERE gene_name = ?
#
# with parameters: ['BC005561']
# No results found for query:
#
#             SELECT distinct gene_id
#             FROM gene
#             WHERE gene_name = ?
#
# with parameters: ['BC017643']
# No results found for query:
#
#             SELECT distinct gene_id
#             FROM gene
#             WHERE gene_name = ?
#
# with parameters: ['BC021891']
# No results found for query:
#
#             SELECT distinct gene_id
#             FROM gene
#             WHERE gene_name = ?
#
# with parameters: ['BC022687']
# No results found for query:
#
#             SELECT distinct gene_id
#             FROM gene
#             WHERE gene_name = ?
#
# with parameters: ['BC023829']
# No results found for query:
#
#             SELECT distinct gene_id
#             FROM gene
#             WHERE gene_name = ?
#
# with parameters: ['BC026585']
# No results found for query:
#
#             SELECT distinct gene_id
#             FROM gene
#             WHERE gene_name = ?
#
# with parameters: ['BC027231']
# No results found for query:
#
#             SELECT distinct gene_id
#             FROM gene
#             WHERE gene_name = ?
#
# with parameters: ['BC029214']
# No results found for query:
#
#             SELECT distinct gene_id
#             FROM gene
#             WHERE gene_name = ?
#
# with parameters: ['BC030336']
# No results found for query:
#
#             SELECT distinct gene_id
#             FROM gene
#             WHERE gene_name = ?
#
# with parameters: ['BC030499']
# No results found for query:
#
#             SELECT distinct gene_id
#             FROM gene
#             WHERE gene_name = ?
#
# with parameters: ['BC030867']
# No results found for query:
#
#             SELECT distinct gene_id
#             FROM gene
#             WHERE gene_name = ?
#
# with parameters: ['BC037034']
# No results found for query:
#
#             SELECT distinct gene_id
#             FROM gene
#             WHERE gene_name = ?
#
# with parameters: ['BC039771']
# No results found for query:
#
#             SELECT distinct gene_id
#             FROM gene
#             WHERE gene_name = ?
#
# with parameters: ['BC048502']
# No results found for query:
#
#             SELECT distinct gene_id
#             FROM gene
#             WHERE gene_name = ?
#
# with parameters: ['BC068281']
# No results found for query:
#
#             SELECT distinct gene_id
#             FROM gene
#             WHERE gene_name = ?
#
# with parameters: ['Bre']
# No results found for query:
#
#             SELECT distinct gene_id
#             FROM gene
#             WHERE gene_name = ?
#
# with parameters: ['Bzrap1']
# No results found for query:
#
#             SELECT distinct gene_id
#             FROM gene
#             WHERE gene_name = ?
#
# with parameters: ['C030027H14Rik']
# No results found for query:
#
#             SELECT distinct gene_id
#             FROM gene
#             WHERE gene_name = ?
#
# with parameters: ['C030039L03Rik']
# No results found for query:
#
#             SELECT distinct gene_id
#             FROM gene
#             WHERE gene_name = ?
#
# with parameters: ['C230004F18Rik']
# No results found for query:
#
#             SELECT distinct gene_id
#             FROM gene
#             WHERE gene_name = ?
#
# with parameters: ['C230088H06Rik']
# No results found for query:
#
#             SELECT distinct gene_id
#             FROM gene
#             WHERE gene_name = ?
#
# with parameters: ['C330006A16Rik']
# No results found for query:
#
#             SELECT distinct gene_id
#             FROM gene
#             WHERE gene_name = ?
#
# with parameters: ['C330027C09Rik']
# No results found for query:
#
#             SELECT distinct gene_id
#             FROM gene
#             WHERE gene_name = ?
#
# with parameters: ['C530050E15Rik']
# No results found for query:
#
#             SELECT distinct gene_id
#             FROM gene
#             WHERE gene_name = ?
#
# with parameters: ['C77370']
# No results found for query:
#
#             SELECT distinct gene_id
#             FROM gene
#             WHERE gene_name = ?
#
# with parameters: ['CAAA01093177']
# No results found for query:
#
#             SELECT distinct gene_id
#             FROM gene
#             WHERE gene_name = ?
#
# with parameters: ['CAAA01147332']
# No results found for query:
#
#             SELECT distinct gene_id
#             FROM gene
#             WHERE gene_name = ?
#
# with parameters: ['Carkd']
# No results found for query:
#
#             SELECT distinct gene_id
#             FROM gene
#             WHERE gene_name = ?
#
# with parameters: ['Casc5']
# No results found for query:
#
#             SELECT distinct gene_id
#             FROM gene
#             WHERE gene_name = ?
#
# with parameters: ['Ccbl1']
# No results found for query:
#
#             SELECT distinct gene_id
#             FROM gene
#             WHERE gene_name = ?
#
# with parameters: ['Ccbl2']
# No results found for query:
#
#             SELECT distinct gene_id
#             FROM gene
#             WHERE gene_name = ?
#
# with parameters: ['Ccdc101']
# No results found for query:
#
#             SELECT distinct gene_id
#             FROM gene
#             WHERE gene_name = ?
#
# with parameters: ['Ccdc108']
# No results found for query:
#
#             SELECT distinct gene_id
#             FROM gene
#             WHERE gene_name = ?
#
# with parameters: ['Ccdc109b']
# No results found for query:
#
#             SELECT distinct gene_id
#             FROM gene
#             WHERE gene_name = ?
#
# with parameters: ['Ccdc129']
# No results found for query:
#
#             SELECT distinct gene_id
#             FROM gene
#             WHERE gene_name = ?
#
# with parameters: ['Ccdc132']
# No results found for query:
#
#             SELECT distinct gene_id
#             FROM gene
#             WHERE gene_name = ?
#
# with parameters: ['Ccdc176']
# No results found for query:
#
#             SELECT distinct gene_id
#             FROM gene
#             WHERE gene_name = ?
#
# with parameters: ['Ccdc23']
# No results found for query:
#
#             SELECT distinct gene_id
#             FROM gene
#             WHERE gene_name = ?
#
# with parameters: ['Ccdc37']
# No results found for query:
#
#             SELECT distinct gene_id
#             FROM gene
#             WHERE gene_name = ?
#
# with parameters: ['Ccdc53']
# No results found for query:
#
#             SELECT distinct gene_id
#             FROM gene
#             WHERE gene_name = ?
#
# with parameters: ['Ccdc55']
# No results found for query:
#
#             SELECT distinct gene_id
#             FROM gene
#             WHERE gene_name = ?
#
# with parameters: ['Ccdc64']
# No results found for query:
#
#             SELECT distinct gene_id
#             FROM gene
#             WHERE gene_name = ?
#
# with parameters: ['Ccdc67']
# No results found for query:
#
#             SELECT distinct gene_id
#             FROM gene
#             WHERE gene_name = ?
#
# with parameters: ['Ccdc79']
# No results found for query:
#
#             SELECT distinct gene_id
#             FROM gene
#             WHERE gene_name = ?
#
# with parameters: ['Ccdc94']
# No results found for query:
#
#             SELECT distinct gene_id
#             FROM gene
#             WHERE gene_name = ?
#
# with parameters: ['Cdk3-ps']
# No results found for query:
#
#             SELECT distinct gene_id
#             FROM gene
#             WHERE gene_name = ?
#
# with parameters: ['Cecr5']
# No results found for query:
#
#             SELECT distinct gene_id
#             FROM gene
#             WHERE gene_name = ?
#
# with parameters: ['Cecr6']
# No results found for query:
#
#             SELECT distinct gene_id
#             FROM gene
#             WHERE gene_name = ?
#
# with parameters: ['Chd3os']
# No results found for query:
#
#             SELECT distinct gene_id
#             FROM gene
#             WHERE gene_name = ?
#
# with parameters: ['Cirh1a']
# No results found for query:
#
#             SELECT distinct gene_id
#             FROM gene
#             WHERE gene_name = ?
#
# with parameters: ['Cml1']
# No results found for query:
#
#             SELECT distinct gene_id
#             FROM gene
#             WHERE gene_name = ?
#
# with parameters: ['Cpsf3l']
# No results found for query:
#
#             SELECT distinct gene_id
#             FROM gene
#             WHERE gene_name = ?
#
# with parameters: ['Csrp2bp']
# No results found for query:
#
#             SELECT distinct gene_id
#             FROM gene
#             WHERE gene_name = ?
#
# with parameters: ['Ctage5']
# No results found for query:
#
#             SELECT distinct gene_id
#             FROM gene
#             WHERE gene_name = ?
#
# with parameters: ['Ctgf']
# No results found for query:
#
#             SELECT distinct gene_id
#             FROM gene
#             WHERE gene_name = ?
#
# with parameters: ['Cxx1a']
# No results found for query:
#
#             SELECT distinct gene_id
#             FROM gene
#             WHERE gene_name = ?
#
# with parameters: ['Cxx1b']
# No results found for query:
#
#             SELECT distinct gene_id
#             FROM gene
#             WHERE gene_name = ?
#
# with parameters: ['Cxx1c']
# No results found for query:
#
#             SELECT distinct gene_id
#             FROM gene
#             WHERE gene_name = ?
#
# with parameters: ['Cyp2c44']
# No results found for query:
#
#             SELECT distinct gene_id
#             FROM gene
#             WHERE gene_name = ?
#
# with parameters: ['Cyr61']
# No results found for query:
#
#             SELECT distinct gene_id
#             FROM gene
#             WHERE gene_name = ?
#
# with parameters: ['D10Jhu81e']
# No results found for query:
#
#             SELECT distinct gene_id
#             FROM gene
#             WHERE gene_name = ?
#
# with parameters: ['D15Ertd621e']
# No results found for query:
#
#             SELECT distinct gene_id
#             FROM gene
#             WHERE gene_name = ?
#
# with parameters: ['D17Wsu92e']
# No results found for query:
#
#             SELECT distinct gene_id
#             FROM gene
#             WHERE gene_name = ?
#
# with parameters: ['D230017M19Rik']
# No results found for query:
#
#             SELECT distinct gene_id
#             FROM gene
#             WHERE gene_name = ?
#
# with parameters: ['D2Wsu81e']
# No results found for query:
#
#             SELECT distinct gene_id
#             FROM gene
#             WHERE gene_name = ?
#
# with parameters: ['D3Ertd254e']
# No results found for query:
#
#             SELECT distinct gene_id
#             FROM gene
#             WHERE gene_name = ?
#
# with parameters: ['D830044I16Rik']
# No results found for query:
#
#             SELECT distinct gene_id
#             FROM gene
#             WHERE gene_name = ?
#
# with parameters: ['D8Ertd82e']
# No results found for query:
#
#             SELECT distinct gene_id
#             FROM gene
#             WHERE gene_name = ?
#
# with parameters: ['D930015E06Rik']
# No results found for query:
#
#             SELECT distinct gene_id
#             FROM gene
#             WHERE gene_name = ?
#
# with parameters: ['D930016D06Rik']
# No results found for query:
#
#             SELECT distinct gene_id
#             FROM gene
#             WHERE gene_name = ?
#
# with parameters: ['DHRSX']
# No results found for query:
#
#             SELECT distinct gene_id
#             FROM gene
#             WHERE gene_name = ?
#
# with parameters: ['Ddx26b']
# No results found for query:
#
#             SELECT distinct gene_id
#             FROM gene
#             WHERE gene_name = ?
#
# with parameters: ['Deb1']
# No results found for query:
#
#             SELECT distinct gene_id
#             FROM gene
#             WHERE gene_name = ?
#
# with parameters: ['Dfna5']
# No results found for query:
#
#             SELECT distinct gene_id
#             FROM gene
#             WHERE gene_name = ?
#
# with parameters: ['Dgcr14']
# No results found for query:
#
#             SELECT distinct gene_id
#             FROM gene
#             WHERE gene_name = ?
#
# with parameters: ['Diap1']
# No results found for query:
#
#             SELECT distinct gene_id
#             FROM gene
#             WHERE gene_name = ?
#
# with parameters: ['Diap2']
# No results found for query:
#
#             SELECT distinct gene_id
#             FROM gene
#             WHERE gene_name = ?
#
# with parameters: ['Diap3']
# No results found for query:
#
#             SELECT distinct gene_id
#             FROM gene
#             WHERE gene_name = ?
#
# with parameters: ['Diexf']
# No results found for query:
#
#             SELECT distinct gene_id
#             FROM gene
#             WHERE gene_name = ?
#
# with parameters: ['Dirc2']
# No results found for query:
#
#             SELECT distinct gene_id
#             FROM gene
#             WHERE gene_name = ?
#
# with parameters: ['Dopey1']
# No results found for query:
#
#             SELECT distinct gene_id
#             FROM gene
#             WHERE gene_name = ?
#
# with parameters: ['Dopey2']
# No results found for query:
#
#             SELECT distinct gene_id
#             FROM gene
#             WHERE gene_name = ?
#
# with parameters: ['Dpcd']
# No results found for query:
#
#             SELECT distinct gene_id
#             FROM gene
#             WHERE gene_name = ?
#
# with parameters: ['Dscr3']
# No results found for query:
#
#             SELECT distinct gene_id
#             FROM gene
#             WHERE gene_name = ?
#
# with parameters: ['Dyx1c1Ccpg1']
# No results found for query:
#
#             SELECT distinct gene_id
#             FROM gene
#             WHERE gene_name = ?
#
# with parameters: ['E130012A19Rik']
# No results found for query:
#
#             SELECT distinct gene_id
#             FROM gene
#             WHERE gene_name = ?
#
# with parameters: ['E130309D14Rik']
# No results found for query:
#
#             SELECT distinct gene_id
#             FROM gene
#             WHERE gene_name = ?
#
# with parameters: ['E330009J07Rik']
# No results found for query:
#
#             SELECT distinct gene_id
#             FROM gene
#             WHERE gene_name = ?
#
# with parameters: ['E430025E21Rik']
# No results found for query:
#
#             SELECT distinct gene_id
#             FROM gene
#             WHERE gene_name = ?
#
# with parameters: ['E530001K10Rik']
# No results found for query:
#
#             SELECT distinct gene_id
#             FROM gene
#             WHERE gene_name = ?
#
# with parameters: ['Eftud1']
# No results found for query:
#
#             SELECT distinct gene_id
#             FROM gene
#             WHERE gene_name = ?
#
# with parameters: ['Enthd2']
# No results found for query:
#
#             SELECT distinct gene_id
#             FROM gene
#             WHERE gene_name = ?
#
# with parameters: ['Ept1']
# No results found for query:
#
#             SELECT distinct gene_id
#             FROM gene
#             WHERE gene_name = ?
#
# with parameters: ['Erbb2ip']
# No results found for query:
#
#             SELECT distinct gene_id
#             FROM gene
#             WHERE gene_name = ?
#
# with parameters: ['Etohi1']
# No results found for query:
#
#             SELECT distinct gene_id
#             FROM gene
#             WHERE gene_name = ?
#
# with parameters: ['Fam101a']
# No results found for query:
#
#             SELECT distinct gene_id
#             FROM gene
#             WHERE gene_name = ?
#
# with parameters: ['Fam101b']
# No results found for query:
#
#             SELECT distinct gene_id
#             FROM gene
#             WHERE gene_name = ?
#
# with parameters: ['Fam103a1']
# No results found for query:
#
#             SELECT distinct gene_id
#             FROM gene
#             WHERE gene_name = ?
#
# with parameters: ['Fam105a']
# No results found for query:
#
#             SELECT distinct gene_id
#             FROM gene
#             WHERE gene_name = ?
#
# with parameters: ['Fam109a']
# No results found for query:
#
#             SELECT distinct gene_id
#             FROM gene
#             WHERE gene_name = ?
#
# with parameters: ['Fam120aos']
# No results found for query:
#
#             SELECT distinct gene_id
#             FROM gene
#             WHERE gene_name = ?
#
# with parameters: ['Fam132a']
# No results found for query:
#
#             SELECT distinct gene_id
#             FROM gene
#             WHERE gene_name = ?
#
# with parameters: ['Fam134a']
# No results found for query:
#
#             SELECT distinct gene_id
#             FROM gene
#             WHERE gene_name = ?
#
# with parameters: ['Fam134b']
# No results found for query:
#
#             SELECT distinct gene_id
#             FROM gene
#             WHERE gene_name = ?
#
# with parameters: ['Fam134c']
# No results found for query:
#
#             SELECT distinct gene_id
#             FROM gene
#             WHERE gene_name = ?
#
# with parameters: ['Fam173b']
# No results found for query:
#
#             SELECT distinct gene_id
#             FROM gene
#             WHERE gene_name = ?
#
# with parameters: ['Fam175a']
# No results found for query:
#
#             SELECT distinct gene_id
#             FROM gene
#             WHERE gene_name = ?
#
# with parameters: ['Fam175b']
# No results found for query:
#
#             SELECT distinct gene_id
#             FROM gene
#             WHERE gene_name = ?
#
# with parameters: ['Fam178a']
# No results found for query:
#
#             SELECT distinct gene_id
#             FROM gene
#             WHERE gene_name = ?
#
# with parameters: ['Fam179a']
# No results found for query:
#
#             SELECT distinct gene_id
#             FROM gene
#             WHERE gene_name = ?
#
# with parameters: ['Fam179b']
# No results found for query:
#
#             SELECT distinct gene_id
#             FROM gene
#             WHERE gene_name = ?
#
# with parameters: ['Fam188a']
# No results found for query:
#
#             SELECT distinct gene_id
#             FROM gene
#             WHERE gene_name = ?
#
# with parameters: ['Fam188b']
# No results found for query:
#
#             SELECT distinct gene_id
#             FROM gene
#             WHERE gene_name = ?
#
# with parameters: ['Fam195a']
# No results found for query:
#
#             SELECT distinct gene_id
#             FROM gene
#             WHERE gene_name = ?
#
# with parameters: ['Fam195b']
# No results found for query:
#
#             SELECT distinct gene_id
#             FROM gene
#             WHERE gene_name = ?
#
# with parameters: ['Fam196a']
# No results found for query:
#
#             SELECT distinct gene_id
#             FROM gene
#             WHERE gene_name = ?
#
# with parameters: ['Fam196b']
# No results found for query:
#
#             SELECT distinct gene_id
#             FROM gene
#             WHERE gene_name = ?
#
# with parameters: ['Fam198a']
# No results found for query:
#
#             SELECT distinct gene_id
#             FROM gene
#             WHERE gene_name = ?
#
# with parameters: ['Fam198b']
# No results found for query:
#
#             SELECT distinct gene_id
#             FROM gene
#             WHERE gene_name = ?
#
# with parameters: ['Fam19a1']
# No results found for query:
#
#             SELECT distinct gene_id
#             FROM gene
#             WHERE gene_name = ?
#
# with parameters: ['Fam19a2']
# No results found for query:
#
#             SELECT distinct gene_id
#             FROM gene
#             WHERE gene_name = ?
#
# with parameters: ['Fam19a5']
# No results found for query:
#
#             SELECT distinct gene_id
#             FROM gene
#             WHERE gene_name = ?
#
# with parameters: ['Fam206a']
# No results found for query:
#
#             SELECT distinct gene_id
#             FROM gene
#             WHERE gene_name = ?
#
# with parameters: ['Fam208a']
# No results found for query:
#
#             SELECT distinct gene_id
#             FROM gene
#             WHERE gene_name = ?
#
# with parameters: ['Fam208b']
# No results found for query:
#
#             SELECT distinct gene_id
#             FROM gene
#             WHERE gene_name = ?
#
# with parameters: ['Fam21']
# No results found for query:
#
#             SELECT distinct gene_id
#             FROM gene
#             WHERE gene_name = ?
#
# with parameters: ['Fam212a']
# No results found for query:
#
#             SELECT distinct gene_id
#             FROM gene
#             WHERE gene_name = ?
#
# with parameters: ['Fam212b']
# No results found for query:
#
#             SELECT distinct gene_id
#             FROM gene
#             WHERE gene_name = ?
#
# with parameters: ['Fam213a']
# No results found for query:
#
#             SELECT distinct gene_id
#             FROM gene
#             WHERE gene_name = ?
#
# with parameters: ['Fam213b']
# No results found for query:
#
#             SELECT distinct gene_id
#             FROM gene
#             WHERE gene_name = ?
#
# with parameters: ['Fam35a']
# No results found for query:
#
#             SELECT distinct gene_id
#             FROM gene
#             WHERE gene_name = ?
#
# with parameters: ['Fam46a']
# No results found for query:
#
#             SELECT distinct gene_id
#             FROM gene
#             WHERE gene_name = ?
#
# with parameters: ['Fam46c']
# No results found for query:
#
#             SELECT distinct gene_id
#             FROM gene
#             WHERE gene_name = ?
#
# with parameters: ['Fam46d']
# No results found for query:
#
# ...
#
#             SELECT distinct gene_id
#             FROM gene
#             WHERE gene_name = ?
#
# with parameters: ['RP23-5D6']
# No results found for query:
#
#             SELECT distinct gene_id
#             FROM gene
#             WHERE gene_name = ?
#
# with parameters: ['RP23-64I9']
# No results found for query:
#
#             SELECT distinct gene_id
#             FROM gene
#             WHERE gene_name = ?
#
# with parameters: ['RP24-127M20']
# No results found for query:
#
#             SELECT distinct gene_id
#             FROM gene
#             WHERE gene_name = ?
#
# with parameters: ['RP24-136N24']
# No results found for query:
#
#             SELECT distinct gene_id
#             FROM gene
#             WHERE gene_name = ?
#
# with parameters: ['RP24-137B5']
# No results found for query:
#
#             SELECT distinct gene_id
#             FROM gene
#             WHERE gene_name = ?
#
# with parameters: ['RP24-159I1']
# No results found for query:
#
#             SELECT distinct gene_id
#             FROM gene
#             WHERE gene_name = ?
#
# with parameters: ['RP24-171J16']
# No results found for query:
#
#             SELECT distinct gene_id
#             FROM gene
#             WHERE gene_name = ?
#
# with parameters: ['RP24-269A16']
# No results found for query:
#
#             SELECT distinct gene_id
#             FROM gene
#             WHERE gene_name = ?
#
# with parameters: ['RP24-272N4']
# No results found for query:
#
#             SELECT distinct gene_id
#             FROM gene
#             WHERE gene_name = ?
#
# with parameters: ['RP24-278I6']
# No results found for query:
#
#             SELECT distinct gene_id
#             FROM gene
#             WHERE gene_name = ?
#
# with parameters: ['RP24-336O24']
# No results found for query:
#
#             SELECT distinct gene_id
#             FROM gene
#             WHERE gene_name = ?
#
# with parameters: ['RP24-338D12']
# No results found for query:
#
#             SELECT distinct gene_id
#             FROM gene
#             WHERE gene_name = ?
#
# with parameters: ['RP24-409C18']
# No results found for query:
#
#             SELECT distinct gene_id
#             FROM gene
#             WHERE gene_name = ?
#
# with parameters: ['RP24-427A8']
# No results found for query:
#
#             SELECT distinct gene_id
#             FROM gene
#             WHERE gene_name = ?
#
# with parameters: ['RP24-475M20']
# No results found for query:
#
#             SELECT distinct gene_id
#             FROM gene
#             WHERE gene_name = ?
#
# with parameters: ['RP24-479J14']
# No results found for query:
#
#             SELECT distinct gene_id
#             FROM gene
#             WHERE gene_name = ?
#
# with parameters: ['RP24-496L23']
# No results found for query:
#
#             SELECT distinct gene_id
#             FROM gene
#             WHERE gene_name = ?
#
# with parameters: ['WI1-2587D24']
# No results found for query:
#
#             SELECT distinct gene_id
#             FROM gene
#             WHERE gene_name = ?
#
# with parameters: ['4930549C01Rik']
# No results found for query:
#
#             SELECT distinct gene_id
#             FROM gene
#             WHERE gene_name = ?
#
# with parameters: ['A130057D12Rik']
# No results found for query:
#
#             SELECT distinct gene_id
#             FROM gene
#             WHERE gene_name = ?
#
# with parameters: ['Als2cr11']
# No results found for query:
#
#             SELECT distinct gene_id
#             FROM gene
#             WHERE gene_name = ?
#
# with parameters: ['D930048G16Rik']
# No results found for query:
#
#             SELECT distinct gene_id
#             FROM gene
#             WHERE gene_name = ?
#
# with parameters: ['Gm10020']
# No results found for query:
#
#             SELECT distinct gene_id
#             FROM gene
#             WHERE gene_name = ?
#
# with parameters: ['Gm13443']
# No results found for query:
#
#             SELECT distinct gene_id
#             FROM gene
#             WHERE gene_name = ?
#
# with parameters: ['Gm21747']
# No results found for query:
#
#             SELECT distinct gene_id
#             FROM gene
#             WHERE gene_name = ?
#
# with parameters: ['Gm21857']
# No results found for query:
#
#             SELECT distinct gene_id
#             FROM gene
#             WHERE gene_name = ?
#
# with parameters: ['Gm26641']
# No results found for query:
#
#             SELECT distinct gene_id
#             FROM gene
#             WHERE gene_name = ?
#
# with parameters: ['Gm26697']
# No results found for query:
#
#             SELECT distinct gene_id
#             FROM gene
#             WHERE gene_name = ?
#
# with parameters: ['Gm26808']
# No results found for query:
#
#             SELECT distinct gene_id
#             FROM gene
#             WHERE gene_name = ?
#
# with parameters: ['Gm42746']
# No results found for query:
#
#             SELECT distinct gene_id
#             FROM gene
#             WHERE gene_name = ?
#
# with parameters: ['Gm684']
# No results found for query:
#
#             SELECT distinct gene_id
#             FROM gene
#             WHERE gene_name = ?
#
# with parameters: ['Hfe2']
# No results found for query:
#
#             SELECT distinct gene_id
#             FROM gene
#             WHERE gene_name = ?
#
# with parameters: ['Hrasls']
# No results found for query:
#
#             SELECT distinct gene_id
#             FROM gene
#             WHERE gene_name = ?
#
# with parameters: ['Lincenc1']
# No results found for query:
#
#             SELECT distinct gene_id
#             FROM gene
#             WHERE gene_name = ?
#
# with parameters: ['RP23-132J21']
# No results found for query:
#
#             SELECT distinct gene_id
#             FROM gene
#             WHERE gene_name = ?
#
# with parameters: ['RP23-166E8']
# No results found for query:
#
#             SELECT distinct gene_id
#             FROM gene
#             WHERE gene_name = ?
#
# with parameters: ['RP23-235M8']
# No results found for query:
#
#             SELECT distinct gene_id
#             FROM gene
#             WHERE gene_name = ?
#
# with parameters: ['RP23-292C5']
# No results found for query:
#
#             SELECT distinct gene_id
#             FROM gene
#             WHERE gene_name = ?
#
# with parameters: ['RP23-307M24']
# No results found for query:
#
#             SELECT distinct gene_id
#             FROM gene
#             WHERE gene_name = ?
#
# with parameters: ['RP23-354H24']
# No results found for query:
#
#             SELECT distinct gene_id
#             FROM gene
#             WHERE gene_name = ?
#
# with parameters: ['RP23-374N15']
# No results found for query:
#
#             SELECT distinct gene_id
#             FROM gene
#             WHERE gene_name = ?
#
# with parameters: ['RP23-470P9']
# No results found for query:
#
#             SELECT distinct gene_id
#             FROM gene
#             WHERE gene_name = ?
#
# with parameters: ['RP23-480I16']
# No results found for query:
#
#             SELECT distinct gene_id
#             FROM gene
#             WHERE gene_name = ?
#
# with parameters: ['RP24-112I14']
# No results found for query:
#
#             SELECT distinct gene_id
#             FROM gene
#             WHERE gene_name = ?
#
# with parameters: ['RP24-194N1']
# No results found for query:
#
#             SELECT distinct gene_id
#             FROM gene
#             WHERE gene_name = ?
#
# with parameters: ['RP24-322F4']
# No results found for query:
#
#             SELECT distinct gene_id
#             FROM gene
#             WHERE gene_name = ?
#
# with parameters: ['RP24-353J16']
# No results found for query:
#
#             SELECT distinct gene_id
#             FROM gene
#             WHERE gene_name = ?
#
# with parameters: ['RP24-358D8']
# No results found for query:
#
#             SELECT distinct gene_id
#             FROM gene
#             WHERE gene_name = ?
#
# with parameters: ['RP24-407P8']
# No results found for query:
#
#             SELECT distinct gene_id
#             FROM gene
#             WHERE gene_name = ?
#
# with parameters: ['RP24-423A5']
# No results found for query:
#
#             SELECT distinct gene_id
#             FROM gene
#             WHERE gene_name = ?
#
# with parameters: ['RP24-425H24']
# No results found for query:
#
#             SELECT distinct gene_id
#             FROM gene
#             WHERE gene_name = ?
#
# with parameters: ['RP24-97D9']
# No results found for query:
#
#             SELECT distinct gene_id
#             FROM gene
#             WHERE gene_name = ?
#
# with parameters: ['Rgag1']
# No results found for query:
#
#             SELECT distinct gene_id
#             FROM gene
#             WHERE gene_name = ?
#
# with parameters: ['Sept14']
# No results found for query:
#
#             SELECT distinct gene_id
#             FROM gene
#             WHERE gene_name = ?
#
# with parameters: ['Vmn2r-ps5']
# No results found for query:
#
#             SELECT distinct gene_id
#             FROM gene
#             WHERE gene_name = ?
#
# with parameters: ['1700011A15Rik']
# No results found for query:
#
#             SELECT distinct gene_id
#             FROM gene
#             WHERE gene_name = ?
#
# with parameters: ['4930435E12Rik']
# No results found for query:
#
#             SELECT distinct gene_id
#             FROM gene
#             WHERE gene_name = ?
#
# with parameters: ['5031414D18Rik']
# No results found for query:
#
#             SELECT distinct gene_id
#             FROM gene
#             WHERE gene_name = ?
#
# with parameters: ['9430007A20Rik']
# No results found for query:
#
#             SELECT distinct gene_id
#             FROM gene
#             WHERE gene_name = ?
#
# with parameters: ['AC073562']
# No results found for query:
#
#             SELECT distinct gene_id
#             FROM gene
#             WHERE gene_name = ?
#
# with parameters: ['Cml3']
# No results found for query:
#
#             SELECT distinct gene_id
#             FROM gene
#             WHERE gene_name = ?
#
# with parameters: ['D330045A20Rik']
# No results found for query:
#
#             SELECT distinct gene_id
#             FROM gene
#             WHERE gene_name = ?
#
# with parameters: ['Fam26e']
# No results found for query:
#
#             SELECT distinct gene_id
#             FROM gene
#             WHERE gene_name = ?
#
# with parameters: ['Gm11612']
# No results found for query:
#
#             SELECT distinct gene_id
#             FROM gene
#             WHERE gene_name = ?
#
# with parameters: ['Gm26755']
# No results found for query:
#
#             SELECT distinct gene_id
#             FROM gene
#             WHERE gene_name = ?
#
# with parameters: ['Gm26780']
# No results found for query:
#
#             SELECT distinct gene_id
#             FROM gene
#             WHERE gene_name = ?
#
# with parameters: ['Gm26819']
# No results found for query:
#
#             SELECT distinct gene_id
#             FROM gene
#             WHERE gene_name = ?
#
# with parameters: ['Gm29593']
# No results found for query:
#
#             SELECT distinct gene_id
#             FROM gene
#             WHERE gene_name = ?
#
# with parameters: ['Gm42415']
# No results found for query:
#
#             SELECT distinct gene_id
#             FROM gene
#             WHERE gene_name = ?
#
# with parameters: ['Gm42485']
# No results found for query:
#
#             SELECT distinct gene_id
#             FROM gene
#             WHERE gene_name = ?
#
# with parameters: ['Gm42810']
# No results found for query:
#
#             SELECT distinct gene_id
#             FROM gene
#             WHERE gene_name = ?
#
# with parameters: ['Gm43261']
# No results found for query:
#
#             SELECT distinct gene_id
#             FROM gene
#             WHERE gene_name = ?
#
# with parameters: ['Gm43455']
# No results found for query:
#
#             SELECT distinct gene_id
#             FROM gene
#             WHERE gene_name = ?
#
# with parameters: ['Gm43537']
# No results found for query:
#
#             SELECT distinct gene_id
#             FROM gene
#             WHERE gene_name = ?
#
# with parameters: ['Gm5868']
# No results found for query:
#
#             SELECT distinct gene_id
#             FROM gene
#             WHERE gene_name = ?
#
# with parameters: ['Gm6768']
# No results found for query:
#
#             SELECT distinct gene_id
#             FROM gene
#             WHERE gene_name = ?
#
# with parameters: ['Gm8822']
# No results found for query:
#
#             SELECT distinct gene_id
#             FROM gene
#             WHERE gene_name = ?
#
# with parameters: ['Pp2d1-ps']
# No results found for query:
#
#             SELECT distinct gene_id
#             FROM gene
#             WHERE gene_name = ?
#
# with parameters: ['RP23-130D15']
# No results found for query:
#
#             SELECT distinct gene_id
#             FROM gene
#             WHERE gene_name = ?
#
# with parameters: ['RP23-14P17']
# No results found for query:
#
#             SELECT distinct gene_id
#             FROM gene
#             WHERE gene_name = ?
#
# with parameters: ['RP23-172P1']
# No results found for query:
#
#             SELECT distinct gene_id
#             FROM gene
#             WHERE gene_name = ?
#
# with parameters: ['RP23-177J21']
# No results found for query:
#
#             SELECT distinct gene_id
#             FROM gene
#             WHERE gene_name = ?
#
# with parameters: ['RP23-184D18']
# No results found for query:
#
#             SELECT distinct gene_id
#             FROM gene
#             WHERE gene_name = ?
#
# with parameters: ['RP23-235P6']
# No results found for query:
#
#             SELECT distinct gene_id
#             FROM gene
#             WHERE gene_name = ?
#
# with parameters: ['RP23-455C13']
# No results found for query:
#
#             SELECT distinct gene_id
#             FROM gene
#             WHERE gene_name = ?
#
# with parameters: ['RP23-49I18']
# No results found for query:
#
#             SELECT distinct gene_id
#             FROM gene
#             WHERE gene_name = ?
#
# with parameters: ['RP23-97L11']
# No results found for query:
#
#             SELECT distinct gene_id
#             FROM gene
#             WHERE gene_name = ?
#
# with parameters: ['RP24-329F21']
# No results found for query:
#
#             SELECT distinct gene_id
#             FROM gene
#             WHERE gene_name = ?
#
# with parameters: ['RP24-462O14']
# No results found for query:
#
#             SELECT distinct gene_id
#             FROM gene
#             WHERE gene_name = ?
#
# with parameters: ['RP24-63G4']
# ---------------------------------------------------------------------------
# ValueError                                Traceback (most recent call last)
# <ipython-input-15-4a940de41330> in <module>
# ----> 1 _get_annotation(adata)
#
# <ipython-input-13-0d6084fb956e> in _get_annotation(adata, retries)
#      85         [adata.var, pd.DataFrame(genes, index=adata.var_names)], axis=1
#      86     )
# ---> 87     adata.var.columns = np.hstack(
#      88         [old_col, np.array(["chr", "start", "end", "strand"])]
#      89     )
#
# ~/anaconda3/envs/openproblem/lib/python3.8/site-packages/pandas/core/generic.py in __setattr__(self, name, value)
#    5150         try:
#    5151             object.__getattribute__(self, name)
# -> 5152             return object.__setattr__(self, name, value)
#    5153         except AttributeError:
#    5154             pass
#
# pandas/_libs/properties.pyx in pandas._libs.properties.AxisProperty.__set__()
#
# ~/anaconda3/envs/openproblem/lib/python3.8/site-packages/pandas/core/generic.py in _set_axis(self, axis, labels)
#     562     def _set_axis(self, axis: int, labels: Index) -> None:
#     563         labels = ensure_index(labels)
# --> 564         self._mgr.set_axis(axis, labels)
#     565         self._clear_item_cache()
#     566
#
# ~/anaconda3/envs/openproblem/lib/python3.8/site-packages/pandas/core/internals/managers.py in set_axis(self, axis, new_labels)
#     224
#     225         if new_len != old_len:
# --> 226             raise ValueError(
#     227                 f"Length mismatch: Expected axis has {old_len} elements, new "
#     228                 f"values have {new_len} elements"
#
# ValueError: Length mismatch: Expected axis has 7 elements, new values have 6 elements

# %%
adata.shape, adata.obsm['mode2'].shape
# Out:
# ((5081, 19322), (5081, 229429))

# %%
adata.var.tail()
# Out:
#          gene_short_name  n_counts      0            1            2  3  \
# genes
# Vsig4              Vsig4       1.0   chrX   96247203.0   96293438.0  -
# Zfp296            Zfp296       1.0   chr7   19577287.0   19580656.0  +
# Zpld1              Zpld1       1.0  chr16   55225175.0   55297986.0  -
# mt-Ta              mt-Ta       1.0  chrMT       5018.0       5086.0  -
# n-R5s158        n-R5s158       1.0   chr7  128774846.0  128774963.0  -
#
#                                                           4
# genes
# Vsig4     [Exon(exon_id='ENSMUSE00000348836', gene_id='E...
# Zfp296    [Exon(exon_id='ENSMUSE00000676834', gene_id='E...
# Zpld1     [Exon(exon_id='ENSMUSE00000501407', gene_id='E...
# mt-Ta     [Exon(exon_id='ENSMUSE00000521525', gene_id='E...
# n-R5s158  [Exon(exon_id='ENSMUSE00000664248', gene_id='E...

# %%
adata.var.loc['Zfp296', 4]
# Out:
# [Exon(exon_id='ENSMUSE00000676834', gene_id='ENSMUSG00000011267', gene_name='Zfp296', contig='7', start=19577287, end=19577628, strand='+'),
#  Exon(exon_id='ENSMUSE00000536375', gene_id='ENSMUSG00000011267', gene_name='Zfp296', contig='7', start=19577817, end=19577960, strand='+'),
#  Exon(exon_id='ENSMUSE00001382046', gene_id='ENSMUSG00000011267', gene_name='Zfp296', contig='7', start=19577829, end=19578467, strand='+'),
#  Exon(exon_id='ENSMUSE00000676833', gene_id='ENSMUSG00000011267', gene_name='Zfp296', contig='7', start=19579613, end=19580656, strand='+')]

# %%
# basic quality control
adata = _filter_has_chr(adata)
adata = _filter_mitochondrial(adata)
adata = _filter_n_genes_max(adata)
adata = _filter_n_genes_min(adata)
adata = _filter_n_cells(adata)

# %%
adata.shape, adata.obsm['mode2'].shape
# Out:
# ((4883, 12940), (4883, 229429))

# %% [markdown]
# ## Normalize

# %%
sc.pp.normalize_total(adata, target_sum=1e4)
sc.pp.log1p(adata)

# %% [markdown]
# # (Joint) Feature selection
#
# * currently selected by top 2000 variable genes

# %%
if 2000 <= adata.shape[1]:
    sc.pp.highly_variable_genes(adata, n_top_genes=2000)
    adata = adata[:, adata.var.highly_variable].copy()

# %%
# sc.pp.regress_out(adata, ["total_counts", "pct_counts_mt"])
# sc.pp.scale(adata, max_value=10)

# %%
# generate peak to gene weight matrix
# remove genes without annotation
adata = adata[
    :, adata.var.loc[:, "chr"].isin(np.unique(adata.uns["mode2_var_chr"]))
].copy()

# %%
adata.shape, adata.obsm['mode2'].shape
# Out:
# ((4883, 1999), (4883, 229429))

# %% [markdown]
# # Regulatory effect score

# %%
# filter atac-seq matrix
sel = np.isin(adata.uns["mode2_var_chr"], adata.var.loc[:, "chr"].unique())
adata.uns["mode2_var"] = adata.uns["mode2_var"][sel]
adata.uns["mode2_var_chr"] = adata.uns["mode2_var_chr"][sel]
adata.uns["mode2_var_start"] = adata.uns["mode2_var_start"][sel]
adata.uns["mode2_var_end"] = adata.uns["mode2_var_end"][sel]
adata.obsm["mode2"] = adata.obsm["mode2"][:, sel]

# %%
adata.shape, adata.obsm['mode2'].shape
# Out:
# ((4883, 1999), (4883, 229429))

# %%
adata.var.loc[:, ["start", "end", "strand"]].head()
# Out:
#                      start          end strand
# genes
# 0610009E02Rik   26445696.0   26459390.0      +
# 0610030E20Rik   72347317.0   72353148.0      +
# 0610040B10Rik  143329247.0  143332704.0      +
# 1110008P14Rik   32377097.0   32381938.0      -
# 1110019D14Rik   13871526.0   14044385.0      +

# %%
# extend tss upstream and downstream
extend_tss = adata.var.loc[:, ["start", "end", "strand"]].apply(
    _chrom_limit, axis=1
)
extend_tss.shape
# Out:
# (1999,)

# %%
if isinstance(extend_tss, pd.DataFrame):
    # should be a series
    extend_tss = extend_tss.iloc[:, 0]

extend_tss = pd.concat(
    [
        adata.var.loc[:, "chr"],
        extend_tss.map(lambda x: x[0]).astype("int32"),
        extend_tss.map(lambda x: x[1]).astype("int32"),
        pd.Series(np.arange(adata.shape[1]), index=adata.var_names),
    ],
    axis=1,
)

# %%
(extend_tss.iloc[:, 1]>0).sum(), (extend_tss.iloc[:, 2]>0).sum()
# Out:
# (1999, 1999)

# %%
# peak summits
peaks = pd.DataFrame(
    {
        "chr": adata.uns["mode2_var_chr"],
        "start": adata.uns["mode2_var_start"].astype("int32"),
        "end": adata.uns["mode2_var_end"].astype("int32"),
    }
)
summits = pd.concat(
    [
        peaks.iloc[:, 0],
        peaks.iloc[:, [1, 2]].mean(axis=1).astype("int32"),
        (peaks.iloc[:, [1, 2]].mean(axis=1) + 1).astype("int32"),
        pd.Series(np.arange(peaks.shape[0])),
    ],
    axis=1,
)

# %%
peaks.shape, summits.shape
# Out:
# ((229429, 3), (229429, 4))

# %% [markdown]
# ## Intersection between peak and TSS(+/- 100kb)

# %%
import pybedtools

# overlap TSS bins with peaks
x = pybedtools.BedTool.from_dataframe(summits)
y = pybedtools.BedTool.from_dataframe(extend_tss)

# %%
#tss_to_peaks = y.intersect(x, wb=True, wa=True, loj=False).to_dataframe()
tss_to_peaks = x.intersect(y, wb=True, wa=True, loj=True)
# Out:
# /Users/qq06/anaconda3/envs/openproblem/lib/python3.8/subprocess.py:849: RuntimeWarning: line buffering (buffering=1) isn't supported in binary mode, the default buffer size will be used
#   self.stderr = io.open(errread, 'rb', bufsize)

# %%
tss_to_peaks = tss_to_peaks.to_dataframe(disable_auto_names=True, header=0,
                                         names=["peak_chr", 
                                                 "peak_summit_left",
                                                 "peak_summit_right", 
                                                 "peak_index", 
                                                 "gene_chr", 
                                                 "gene_bin_start", 
                                                 "gene_bin_end", 
                                                 "gene_index"])
print(tss_to_peaks.shape)
# Out:
# (236434, 8)

# %%
tss_to_peaks
# Out:
#        peak_chr  peak_summit_left  peak_summit_right  peak_index gene_chr  \
# 0          chr1           3012927            3012928           1        .
# 1          chr1           3030707            3030708           2        .
# 2          chr1           3071626            3071627           3        .
# 3          chr1           3078844            3078845           4        .
# 4          chr1           3094961            3094962           5        .
# ...         ...               ...                ...         ...      ...
# 236429     chrY          90739912           90739913      229424        .
# 236430     chrY          90740481           90740482      229425        .
# 236431     chrY          90741145           90741146      229426        .
# 236432     chrY          90741964           90741965      229427        .
# 236433     chrY          90744496           90744497      229428        .
#
#         gene_bin_start  gene_bin_end gene_index
# 0                   -1            -1          .
# 1                   -1            -1          .
# 2                   -1            -1          .
# 3                   -1            -1          .
# 4                   -1            -1          .
# ...                ...           ...        ...
# 236429              -1            -1          .
# 236430              -1            -1          .
# 236431              -1            -1          .
# 236432              -1            -1          .
# 236433              -1            -1          .
#
# [236434 rows x 8 columns]

# %%
# remove non-overlapped TSS and peaks
tss_to_peaks = tss_to_peaks.loc[
    (tss_to_peaks.gene_chr != ".") | (tss_to_peaks.gene_index != "."), :
]

# %%
tss_to_peaks
# Out:
#        peak_chr  peak_summit_left  peak_summit_right  peak_index gene_chr  \
# 74         chr1           4412619            4412620          75     chr1
# 75         chr1           4413988            4413989          76     chr1
# 76         chr1           4414410            4414411          77     chr1
# 77         chr1           4414755            4414756          78     chr1
# 78         chr1           4427074            4427075          79     chr1
# ...         ...               ...                ...         ...      ...
# 236371     chrX         169275320          169275321      229366     chrX
# 236372     chrX         169299854          169299855      229367     chrX
# 236373     chrX         169304154          169304155      229368     chrX
# 236374     chrX         169320459          169320460      229369     chrX
# 236419     chrY           1010485            1010486      229414     chrY
#
#         gene_bin_start  gene_bin_end gene_index
# 74             4397354       4597354       1642
# 75             4397354       4597354       1642
# 76             4397354       4597354       1642
# 77             4397354       4597354       1642
# 78             4397354       4597354       1642
# ...                ...           ...        ...
# 236371       169268189     169468189        203
# 236372       169268189     169468189        203
# 236373       169268189     169468189        203
# 236374       169268189     169468189        203
# 236419          910543       1110543        539
#
# [46475 rows x 8 columns]

# %%
(tss_to_peaks.iloc[:, 1] >0).sum(), (tss_to_peaks.iloc[:, 2] >0).sum()
# Out:
# (46475, 46475)

# %%
tss_to_peaks.shape, (tss_to_peaks.iloc[:, 5] >0).sum(), (tss_to_peaks.iloc[:, 6] >0).sum()
# Out:
# ((46475, 8), 46475, 46475)

# %%
tss_to_peaks.apply(
    lambda x: abs((int(x[5]) + int(x[6])) / 2 - int(x[1])) * 1.0 / 1e5, axis=1
).values
# Out:
# array([8.4735e-01, 8.3366e-01, 8.2944e-01, ..., 6.4035e-01, 4.7730e-01,
#        5.8000e-04])

# %%
tss_to_peaks.shape
# Out:
# (46475, 8)

# %% [markdown]
# ## Peak to gene distance weighted by MARGE

# %%
tss_to_peaks.loc[:, "distance"] = tss_to_peaks.apply(
    lambda x: abs((int(x[5]) + int(x[6])) / 2 - int(x[1])) * 1.0 / 1e5, axis=1
)
# Out:
# /Users/qq06/anaconda3/envs/openproblem/lib/python3.8/site-packages/pandas/core/indexing.py:1596: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   self.obj[key] = _infer_fill_value(value)
# /Users/qq06/anaconda3/envs/openproblem/lib/python3.8/site-packages/pandas/core/indexing.py:1745: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   isetter(ilocs[0], value)

# %%
alpha = -np.log(1.0 / 3.0) * 1e5 / 1e4
alpha
# Out:
# 10.986122886681098

# %%
decay_score = np.exp(-alpha * tss_to_peaks["distance"].values)
tss_to_peaks["weight"] = 2.0 * decay_score / (1.0 + decay_score)
# Out:
# <ipython-input-187-127b6076b46a>:2: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   tss_to_peaks["weight"] = 2.0 * decay_score / (1.0 + decay_score)

# %%
tss_to_peaks["weight"]
# Out:
# 74        0.000181
# 75        0.000211
# 76        0.000221
# 77        0.000229
# 78        0.000886
#             ...
# 236371    0.000074
# 236372    0.001097
# 236373    0.001760
# 236374    0.010506
# 236419    0.996814
# Name: weight, Length: 46475, dtype: float64

# %%
(tss_to_peaks["weight"]>0.9).sum()
# Out:
# 2488

# %%
(tss_to_peaks.weight.values > 0).sum()
# Out:
# 46475

# %%
import scipy
gene_peak_weight = scipy.sparse.csr_matrix(
    (
        tss_to_peaks.weight.values,
        (tss_to_peaks.gene_index.astype("int32").values, tss_to_peaks.peak_index),
    ),
    shape=(adata.shape[1], adata.uns["mode2_var"].shape[0]),
)

# %%
(adata.shape[1], adata.uns["mode2_var"].shape[0])
# Out:
# (1999, 229429)

# %%
np.max(tss_to_peaks.gene_index.astype("int32").values)
# Out:
# 1998

# %%
tss_to_peaks.peak_index.max()
# Out:
# 229414

# %%
gene_peak_weight.shape
# Out:
# (1999, 229429)

# %%
adata.obsm["gene_score"] = adata.obsm["mode2"] @ gene_peak_weight.T

# %%
adata.obsm["gene_score"].toarray()
# Out:
# array([[0.00000000e+00, 3.15824245e-01, 0.00000000e+00, ...,
#         0.00000000e+00, 0.00000000e+00, 0.00000000e+00],
#        [1.97660063e+00, 0.00000000e+00, 0.00000000e+00, ...,
#         0.00000000e+00, 0.00000000e+00, 0.00000000e+00],
#        [2.96957805e+00, 0.00000000e+00, 0.00000000e+00, ...,
#         0.00000000e+00, 0.00000000e+00, 6.41954388e-04],
#        ...,
#        [9.88300313e-01, 1.53529093e-04, 0.00000000e+00, ...,
#         0.00000000e+00, 0.00000000e+00, 3.34517093e-01],
#        [1.98077570e+00, 1.58105026e-04, 0.00000000e+00, ...,
#         0.00000000e+00, 0.00000000e+00, 1.88800459e-01],
#        [4.07461852e-03, 0.00000000e+00, 0.00000000e+00, ...,
#         0.00000000e+00, 0.00000000e+00, 0.00000000e+00]])

# %%
adata.obsm["gene_score"]
# Out:
# <4883x1999 sparse matrix of type '<class 'numpy.float64'>'
# 	with 3216015 stored elements in Compressed Sparse Row format>

# %%
adata
# Out:
# AnnData object with n_obs × n_vars = 4883 × 1999
#     obs: 'n_genes_by_counts', 'total_counts', 'total_counts_mt', 'pct_counts_mt', 'n_genes'
#     var: 'gene_short_name', 'n_counts', 'chr', 'start', 'end', 'strand', 'mt', 'n_cells_by_counts', 'mean_counts', 'pct_dropout_by_counts', 'total_counts', 'n_cells', 'highly_variable', 'means', 'dispersions', 'dispersions_norm'
#     uns: 'mode2_obs', 'mode2_var', 'mode2_var_chr', 'mode2_var_start', 'mode2_var_end', 'species', 'version', 'release', 'log1p', 'hvg'
#     obsm: 'mode2', 'gene_score'

# %% [markdown]
# # Imputation of single cell RNA-seq

# %%
import scanpy as sc

# %%
sc.pp.pca(adata)

# %%
sc.pp.neighbors(adata, n_neighbors=300)

# %%
adata.layers['X_knn'] = adata.obsp['connectivities'].dot(adata.X)

# %% [markdown]
# # Imputatation of single cell ATAC-seq

# %%
adata.layers['gene_score_knn'] = adata.obsp['connectivities'].dot(adata.obsm["gene_score"])

# %% [markdown]
# # Metrics

# %% [markdown]
# ## Across genes

# %%
from scipy.stats import pearsonr
cors = []
for i in range(adata.layers['X_knn'].shape[0]):
    cors.append(pearsonr(adata.layers['X_knn'].toarray()[i],
                         adata.layers['gene_score_knn'].toarray()[i]))

# %%
cors_cor = list(map(lambda x: x[0], cors))
sns.kdeplot(np.array(list(cors_cor)))
# Out:
# <AxesSubplot:ylabel='Density'>

# %%
np.median(np.array(list(cors_cor)))
# Out:
# 0.041109396421711186

# %% [markdown]
# ## Across pseudo-bulk cell aggregates by KNN

# %%
from scipy.stats import pearsonr
cors = []
for i in range(adata.layers['X_knn'].shape[1]):
    cors.append(pearsonr(adata.layers['X_knn'].toarray()[:, i],
                         adata.layers['gene_score_knn'].toarray()[:, i]))
# Out:
# /Users/qq06/anaconda3/envs/openproblem/lib/python3.8/site-packages/scipy/stats/stats.py:3845: PearsonRConstantInputWarning: An input array is constant; the correlation coefficent is not defined.
#   warnings.warn(PearsonRConstantInputWarning())

# %%
cors_cor = np.array(list(map(lambda x: x[0], cors)))
sns.kdeplot(cors_cor)
# Out:
# <AxesSubplot:ylabel='Density'>

# %%
np.median(cors_cor[~np.isnan(cors_cor)])
# Out:
# 0.2638835345994894

# %% [markdown]
# ## Global correlation

# %%
def _global_pearson(x, y):
    numerator = np.mean((x - x.mean()) * (y - y.mean()))
    denominator = x.std() * y.std()
    if denominator == 0:
        return 0
    else:
        result = numerator / denominator
        return result

# %%
_global_pearson(adata.layers['X_knn'].toarray(),
                adata.layers['gene_score_knn'].toarray())
# Out:
# 0.08920917476125206
